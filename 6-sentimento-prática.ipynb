# %% [markdown]
# # Análise de sentimento: prática
# Este notebook é parte da documentação de uma exploração de dados realizada para o artigo _**O uso da Cloroquina no tratamento da Covid-19 debatido no Facebook**: um estudo em opinião pública com processamento de linguagem natural_.
#
# Para calcular o sentimento, o TextBlob calcula _polaridade_ e _subjetividade_ tirando uma média dos valores atribuídos aos termos usados no texto analisado. [Neste link](https://planspace.org/20150607-textblob_sentiment/) tem uma explicação de como isso funciona por debaixo dos panos. Esse tipo de abordagem é chamada de _rule-based_, que é uma técnica _knowledge-based_: ou seja, é baseada em regras construídas a partir de corpus de texto tageados por humanos; não é uma forma muito sofisticada, mas é um bom começo.
#
# Existem abordagens estatísticas desse problema também. Uma dessas é o classificador [Naive-Bayes](https://www.ic.unicamp.br/~rocha/teaching/2011s2/mc906/aulas/naive-bayes-classifier.pdf), uma técnica relativamente simples que usa estatística Bayesiana para calcular a probabilidade de uma dada entidade pertencer a uma certa categoria a partir de seus aspectos. Esse método usa aprendizagem de máquina para treinar o modelo. O TextBlob tem uma [implementação](https://textblob.readthedocs.io/en/dev/classifiers.html) dele, e [aqui](https://www.kaggle.com/leandrodoze/sentiment-analysis-in-portuguese) há um exemplo dessa implementação usando o [SciKit Learn](https://scikit-learn.org/stable/).

# %% [markdown]
# ## Importando e lendo os dados
# Começando pelo mais fácil.

# %%
# montando o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Caminho dos arquivos
# !ls '/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/conteúdo'
# Out:
# content1.csv  content3.csv  content5.csv  content7.csv
# content2.csv  content4.csv  content6.csv

# %%
# lendo os dados
data1 = open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/conteúdo/content1.csv')
data1 = data1.read()

# %% [markdown]
# ## Nossa língua portuguesa
# Por mais que o TextBlob "esteja nos ombros de gigantes" como o [NLTK](https://www.nltk.org/), eles não parecem detectar nem analisar língua portuguesa tão de boas assim por padrão não.

# %%
# em português = Sentiment(polarity=0.0, subjectivity=0.0)
from textblob import TextBlob

t = TextBlob("eu estou tão triste")
t.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
# em inglês = Sentiment(polarity=-0.5, subjectivity=1.0)
u = TextBlob("i am so sad")
u.sentiment
# Out:
# Sentiment(polarity=-0.5, subjectivity=1.0)

# %%
# no entanto, ele parece saber com o que está lidando
t.detect_language()
# Out:
# 'pt'

# %% [markdown]
# Abaixo, uma tentativa de levantar o sentimento de cada comentário de um dos datasets. Apenas uma ou outra palavra parece ser identificada e avaliada, provavelmente aquelas com origem e radical comum a palavras da língua inglesa.

# %%
# importando NLTK e o punkt
import nltk
nltk.download('punkt')

teste1 = TextBlob(data1)

# essa função pega o dataset e exibe sentimento linha a linha. Ou pelo menos tenta. :-/
def sent(data):
  for sentence in data.sentences:
    print(sentence.sentiment, '==>', sentence)

sent(teste1)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Conteúdo
# Os casos eram graves ?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estavam com respiradores?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ac
# Somente casos graves estão usando cloroquina
# Up
# Glória à Deus!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ac
# Gloria a Deus ❤️
#
# Deus e maravilho
# Amém
# Amém!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Que continue dando certo a todos
# Tomara
# Isso não é nem perto de ser a solução
# Para de pensar negativo.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Por isso que o brasil nao vai pra frente
# Amém 🙏
# Deve ser Feike!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 1
# Não é.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 75 anos, estava em estado grave e já tinha até se despedido da família.
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/22/mae-de-donos-da-prevent-senior-e-tratada-com-cloroquina-temos-esperanca.htm Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança" UOL.COM.BR Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança" Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança"
# difícilmente ele irá postar algo fake.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Para de pensar negativo.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Por isso que o brasil nao vai pra frente 1
# Isso para quem consegue comprovar que tem o vírus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 🙏🏼 🙏🏼 🙏🏼
# Lembrando que não é só o uso de cloroquina
# É em conjunto com a Azitromicina.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> e um coquetel junto com.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Oxacilina, rinfanpricina
# só tem uma coisa se eu ficar nessa situação morrendo sem ar tomem essa atitude comigo mesmo com todos os efeitos colaterais que tiver!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Se formos ler bula não nos tratamos para nada tudo tem ou pode ter efeito colateral
#
# Amém 🙏
# Amém Deus todo poderoso que está no meio de nós ❤️ 🙏
# Glória Deus
# Onde vc viu isso pra Amim compartilhar?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Q seja verdade e q acabe logo com isso!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Deus nos abençoe
# Datena
# 🙏 🙏 🙏 🙏 graças a deus tomara que continue assim
# Para de passar informação errada galera.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A cloroquina precisa ser associada com todo um protocolo de tratamento.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Aí vem os imbecil que nem doente está e sai comprando, deixando quem depende do medicamento sem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> falaram que agora somente pode comprar com permissão de um médico
# Ta certo
# tomara que as drogarias sigam as instruções!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> mas por enquanto é só para quem está muito ruim para casos leves ou prevenção não precisa!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> O problema é que o pessoal não entende isso!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Já saiu inclusive várias reportagens sobre o fato da galera estar comprando sem necessidades.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 🙏
#
# Tomara q seja verdade.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Amem
# Não adianta nada ele hospedeiro intermediário sintomas acabam mas ele passa a doença
# acho que não hein Quando a pessoa fica em alta e porque ja foi curada Esta sem o virus no corpo
# vírus sofre mutação se ela esta imune ela pessoa mas perigosa porque ela não vai ter mas sintomas só passa a doença.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> acredito que não Não ouvi ninguém falar isso Quando o infectado e curado pode sim pegar novamente se não se prevenir Mas o virus desaparece No mundo todo já são mais de 100 mil curados
# Povo querido cuidado com estas informações.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Nao tome medicamentos sem prescricao médica.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Datena e batti
# Tá passando tv
# meus amores sou enfermeira com pós em emergência e UTI.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não faça isso.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ainda não temos comprovações que realmente ele é eficaz contra o vírus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos lutando diariamente contra s morte.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos preocupados com todos.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos lutando o tempo todo .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Nos ajudem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Beijos
# Graças à Deus 🙏🏻
# A imagem pode conter: 1 pessoa, texto que diz "cartunistamachado ODEBATE DO SÉCULO DESTE LADO DO RINGUE ELE, CIENTISTA, PHD, POS GRADUADO PELA SOURBONNE... E DESTE LADO o DESAFIANTE COM SUA OMSUA CONTA NO FACEBOOK!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> macrads."
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Gente isso é verdade,Glória Deus.
# Sentiment(polarity=-0.075, subjectivity=0.1) ==> Amém mas não devemos acabar com os estoques, devemos deixar para quem realmente vai precisar
# Poxa uma notícia maravilhosa dessas e o que tem de comentários negativos por aqui.. parece que só gostam de notícias ruins .. Que muitas outras pessoas tenham altas ... ❤️
# Tomare não seja mentira aqui na Net tá saindo muitas notícias falsas Se for vdd que Deus nos ajude
# Amém no Amapá tb estão usando
# Se for verdade mesmo, que Deus nos ajude !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> é verdade simmm
# Glória a Deus !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: uma ou mais pessoas
# Isso é sério!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Poxa não vamos passar notícias falsas não por favor esse momento de medo e dor..
#
# glória a Deus começaram a aparecer boas notícias que assim continue 👏🏻 👏🏻 🙏🏼 🙏🏼 🙏🏼
#
# Isso sim é uma boa notícia 👏 👏 👏 👏
# Será verdade espero q sim m n vi nada vinda do governo...se for mesmo saberemos logo
# ISSO É QUE NEM ESTAMOS NO PICO E JÁ TEM GENTE DESESPERADO
# Graças a Deus 💞
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# eu tava lendo a bula mas não entendi muito bem, os efeitos colaterais desse remédio me corrijam e me desculpem se eu estiver errada mas os efeitos colaterais não pareceu tão graves, E se não for porque não ultilizar em quem estiver prescisando?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> estão usando como protocolo em pacientes graves... Junto com outros medicamentos..
# hum entendi obrigada
# Pode passar a fonte?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> https://istoe.com.br/quatro-pacientes-de-uti-com-coronavirus-tem-alta-apos-uso-de-hidroxicloroquina/ Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente ISTOE.COM.BR Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente
# obrigado!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Vai dar certo fe em Deus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Esse remédio só está sendo usado em pacientes que estão na uti com acompanhamento médico e autorização da familia.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ainda está em análise.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Nas farmácias so vende por intermédio de receitas.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Então quem tá com suspeita não vá atr… Ver mais
# eles usaram fosfato de cloroquina, utilizado para limpeza de aquário e não o hidroxicloroquina.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> na reportagem está hidróxicloroquina
# Então essa que você viu foi muito tendenciosa agindo de má fé, porque não foi hidroxicloroquina
# https://istoe.com.br/quatro-pacientes-de-uti-com-coronavirus-tem-alta-apos-uso-de-hidroxicloroquina/ Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente ISTOE.COM.BR Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente
# estou falando do casal que você citou, que tomou medicamento e o homem veio a falecer...
# entendi desculpe o casal foi cloraquina mesmo
# Fonte ?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> vai procurar, preguiça de gente preguiçosa.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> , tem gente torcendo contra, aff...pior que o próprio vírus ...
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# blza, achei
# Que maravilha!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Será que existe alguém com mais de 60 anos nesse grupo que se recuperou?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> dizeram que tem um senhor de 75 anos que estava em estado grave e se despediu de sua familia acreditando que iria falecer Mas graças a Deus passa bem
# Datena mostrando o cientista!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É verdade sim ,tá passando na Record agora,tô assistindo
# Caraca, não tem nem 24 horas que o ministério da saúde definiu o protocolo de uso da cloroquina e liberou o uso em pacientes graves e já tem gente curada?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> O remédio é bom demais.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> estava em off-label, já estava sendo usado a mais de uma semana...
# Aí sim, então pode ser verdade a notícia, que bom.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Rezar para não ter recaida.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Obrigado pela informação.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> kkkkkkkkkkkk Mas que foi engraçada a sua postagem, isso foi !!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Eu tento não fazer isso mas as vezes escapa, é tanta notícia desencontrada que desanima
# Pior que quando eu li pensei exatamente a mesma coisa... Ai vi seu post e era o que eu ia postar kkkkk
# E vrd está passando no jornal !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: 1 pessoa, texto que diz "ப" H /PA PACIENTES TRATADOS COM CLOROQUINA RECEBEM ALTA DA UTI EM SÃO PAULO"
# Graças a Deus
# 4Altas e 1 morte e outra em estado grave devido a essa medicação, pesquisem direito .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> O que morreu é a que está em estado grave tomou por conta própria não teve orientação médica!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> no q vi , cada organismo tem uma reação, e por ser divulgado mtos já estao indo atrás da medicação pois a demora e a falta de exame faz com q isso aconteça, !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Mtos se auto medicam sem nem ir ao hospital, e agra mtos vão e são orientad… Ver mais
# concordo !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Bom que agora não são todos que terão acesso , somente com receitas médicas.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E daí .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> O povo eim Graças a Deus pelos 4e antes que todos morriam !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> a postagem é sobre os que tiveram alta .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Leia direito
# eu li , e tbm respondi oq tbm li !
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Apenas repassei oq vi , a respeito se puder ler meu texto e interpretar VC vai ver.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Glórias a DEUS 🙏🏻❤
# Está passando no R7 mas é incrível como tem gente negativa, aff!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Vamos torcer para que não tenha nenhum efeito após o uso.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Eu na minha casa 🏠 Vc na sua casa 🏡 E Deus na casa de todos nós 🙏 🙏 🙏
# Vão esperar passar na globolixo?que nada,a única coisa que vão ouvir vai ser: Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,
# , vd
# ou então panelaço , panelaço
# ,panelaço gravado num pendriver
# esse panelaço e do tempo da Dilma ainda.... #globo lixo .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos em vantagem ALQUEM tem q ser cobaia 0:00 / 0:02
# Noticia boa
# Mas não e para todos hello
# Senra explicou que os resultados não fazem parte da coalizão covid-19, feita pelo Hospital Israelita Albert Einstein, HCor, Sírio Libanês e BRICNet, uma rede que realiza estudos clínicos na área de medicina intensiva.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> O especialista ainda fez questão de ressaltar que não há comprovação de causa e efeito do uso da hidroxicloroquina.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ou seja, não é possível garantir que os pacientes foram curados graças ao medicamento.... - Veja mais em https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm?cmpid=copiaecola Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# 🙏 🙏 🙏 🙏 🙏
# Graças a Deus
# Teve mais mas não falam
# Meu Deus..sera verdade??
# Sentiment(polarity=0.0, subjectivity=0.0) ==> ?.no meio desse caos..a gente nao sabe mais no que acreditar.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> , está passando no R7
# .....vou ver querida...obrigada
# A imagem pode conter: 2 pessoas, pessoas em pé
# Fontes?!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> vai procurar, preguiça de gente preguiçosa.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> ²
# O Dono da postagem é a fonte .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 👍 Ele sempre da notícias verdadeiras aqui
# kkkkk Hoje a música perdeu 2 pessoas para o Coronavirus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Muito triste.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> , ah, nossa!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Se a pessoa faz uma postagem dessa, o certo é citar a fonte, né, não?!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não é questão de preguiça, é questão de lógica...
# Licença gente, foi noticiado agora pouco, nos jornais da rede Bandeirantes, e Record.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Na rede Record hj a noite passará uma reportagem exclusiva sobre o assunto.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A informação é verídica 👍
# A imagem pode conter: 2 pessoas, pessoas em pé
# , obrigada!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> M ♥️ ♥️ ♥️
# A mãe do meu compadre está na UTI e começou a usar esse medicamento ontem, hoje ela já teve melhora 🙏 🙏
# poste quando ela tiver alta, vamos nos animar e que Deus restaure a saúde e abençoe todos os doentes e acabe com a força desse vírus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Amém
# postarei qndo ela tiver alta 🙏
# isso, porque ai temos mas uma esperança.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Graças a Deus 🙏
# , é uma boa ideia !!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Graça à Deus Amém senhor 🙏 🙏 🙏
# No balanço geral de São Paulo está passando agora
# Olha ,sei que devemos ter cautela ,porém gente ,que benção está sendo ,pessoas curadas,pessoas que estão vencendo esse vírus!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Que isso possa acontecer com todos os que pegarem o vírus ,vamos nos unir em oração ,para que tudo isso passe logo ,e as pesso… Ver mais
# Gente se liga nas notícias viu?
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> Este perfil é Fake!
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> O Facebook está lotado de perfis FAKE espalhando Fakenews!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Perfis sem fotos de família e de seus dias a dias e comentários algum!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fiquem eapertos!
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> esse q postou a notícia se eu não me engano é quem criou essa página , ele sempre atualiza vários números e sempre da certinho
# Bom meu caro, a notícia não é fake.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Passou nos jornais, da rede Bandeirantes e no cidade alerta agora pouco.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Inclusive na Record hj passará uma reportagem especial sobre esse assunto 👍
# A notícia não é falsa.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# ta sobrando dinheiro para a indenização ou vai se desculpar?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pausar GIF Tenor
# em quanto isso na minha cidade , o Corona Virus deve estar pulando d felicidade.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: texto que diz "TIM TIM 18:46 Pesquisar no Facebook 10 Amanhã vai ter protesto pedindo a reabertura do comércio em Presidente Prudente Ver mais PROTESTO PEDINDO ABERTURA DO COMÉRCIO EM PRESIDENTE PRUDENTE CONVITE COMERCIANTES, EMPRESÁRIOS.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> MOTOCICLISTA MOTORISTA TAXISTAS, TODOS TRABALHADORES UTÔNOMOS!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> \*EVENTO PACIFICO SEM FINS POLÍTICOS!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> VOLTA PRUDENTE!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 27/03 12H AV.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> CEL.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> JOSÉ SOARES MARCONDES, PARTIDA EM FRENTE À APEA"
# mas nao quer dizer que estao curados,,,,,
# Dizem que o virus some do corpo do ex infectado Mas corre risco de pegar de novo se não se prevenir São mais de 100 mil curados no mundo todo
# Não existe comprovação da eficácia pela OMS
# exite sim só que oque acontece é qure fora do Brasil os médicos não são habilitados com o medicamento não sabendo a dosagem pois é pouco usado como no Brasil tem mais o uso foi liberado
# OMS é quem regula tudo!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> OMS ja testou tudo q o Brasil usa e ainda vai usar.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Já testou sim se não fosse testa nem o ministério da saúde e nem a anvisa libera.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Só liberaram no Brasil porque os médicos conhecem o medicamento é a dosagem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: texto que diz "Atenção Usuário Facebook Gente se liga nas notícias viu?
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> Este perfil é Fake!
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> o Facebook está lotado de perfis FAKE espalhando Fakenews e afumentando o ódio entre pessoas!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Perfis sem fotos de família e de seus dia-a-dia nenhum comentário!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fiquem espertos!"
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estava a 15 minutos, escutando o ministro da saúde é não falou nisso
# A imagem pode conter: 2 pessoas, pessoas em pé
# Lembrando que essa medicação é perigosa e só pode ser usada no hospital e administrada pela equipe médica no caso de corona.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Nada de se automedicar gente
# A imagem pode conter: texto que diz "Atenção Usuário Facebook Gente se liga nas notícias viu?
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> Este perfil é Fake!
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> o Facebook está lotado de perfis FAKE espalhando Fakenews e afumentando o ódio entre pessoas!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Perfis sem fotos de família e de seus dia-a-dia e nenhum comentário!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fiquem espertos!"
# Sentiment(polarity=0.0, subjectivity=0.0) ==> a notícia não é falsa, passou nos jornais.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# A imagem pode conter: 2 pessoas, pessoas em pé
#
# A imagem pode conter: texto que diz "ALERTA PARA o MUNDO Economista do FMI que pedia fim da quarentena para salvar economia morre de coronavírus em Washington Rogério Correia"
# A imagem pode conter: 1 pessoa, texto que diz "17:30 https://www.metropoles.com/dis.. ETRÓPOLES Cofen Coren #EnfermagomContraCoronavirus DISTRITO FEDERAL Segurança de Bolsonaro está em estado grave com coronavírus "Ele sempre viaja com o presidente.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Eu acredito que esse vírus ele adquiriu nessas viagens' disse mãe do PM ao Metrópoles REPRODUÇÃO"
# Acabei de ficar sabendo q morreu foi gente tomando esse medicamento
# sem orientações de um médico
# Esse medicamento tem efeitos colaterais sérios, causa até cegueira
# https://www.covidvisualizer.com/?fbclid=IwAR2sRoHpl8GeEqr8A9ZyZ17hPGMmS4HH1q87fFFicm_eK0v9sRS5LGQSN68 COVID-19 Visualizer COVIDVISUALIZER.COM COVID-19 Visualizer COVID-19 Visualizer
# Nego enche o cu de cocaína, mas o que mata é minha cloroquina... Nenhuma descrição de foto disponível.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Tu sem lúpus?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Tu tem corona?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Salvar um desconhecido de lupus com uma caixa, salvar 6 famíliares de corona com uma caixa, eis a questão.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não se automedique moça.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não sabe a posologia, não sabe os efeitos adversos, simplesmente você não sabe.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> eu vi
# Qual fonte?
# Sentiment(polarity=0.625, subjectivity=0.5) ==> passou na TV Band
# ok
# Passou nos jornais A imagem pode conter: 2 pessoas, pessoas em pé
# Vamos torcer e rezar para que esta pandemia acabe logo!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Temos que ter FÉ !!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 🙏 🙏 🙏 🙏 👏 👏 👏 👏
# https://www.bbc.com/portuguese/brasil-52044400 Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França BBC.COM Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França
# Sabem como e Brasil ne, se consegue comprar remédios proibidos sabe se lá origem ... ficar espalhando essas notícias ajuda em nada.
# Sentiment(polarity=-0.5208333333333334, subjectivity=1.0) ==> É FAKE É FAKE É FAKE É FAKE É FAKE É FAKE
# A imagem pode conter: 1 pessoa, texto que diz "u!"
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> /P RECEBEM PACIENTES TRATADOS COM CLOROQUINA ALTA DA UTI EM SÃO PAULO"
# A imagem pode conter: 2 pessoas, pessoas em pé
# Não é fake.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Passou nos jornais A imagem pode conter: 2 pessoas, pessoas em pé
# acusar sem provas é crime e pode gerar uma indenização por danos morais.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Cuidado com as palavras em público.
# Sentiment(polarity=-0.625, subjectivity=1.0) ==> propagar fake news é crime!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> deixa eles tomarem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Vai ser bom p o Brasil 🤣 👍🏻
# TOMEM DESGRAÇA TOMEM!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 😅 😅 😅
# Gente.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> NAO TOMA ESSE REMÉDIO.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> ele é para ser usado no hospital através do soro.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Tem um casal que morreu hoje por usar esse remédio em casa.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não sejam burros.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Remédio só se tiver doente.… Ver mais
# não foi hj e não foi cloroquina... Mas sim fosfato de cloroquina... É bem diferente... A imagem pode conter: texto que diz "TEXAS Homem morre após ingerir cloroquina, medicamento testado contra a Covid-19 Paciente tomou fosfato de cloroquina junto sua esposa, ainda está internada, hospital orte-americano orientou sobre os perigos da automedicação Por DA REDAÇÃO Ter, 24/03/20 08h38 520 09:50 Bernardo P Küster A mídia faz pânico hoje pois um casal morreu tomando cloroquina, potencial cura para vírus chinês.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> o eles contam APENAS FIM da reportagem é que casal tomou fosfato de cloroquina, usado para limpar aquários, e como prevenção.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pap!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Como respeitar mídia, meu Deus!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> ganância.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fosfato de cloroquina medicamento, a cloroquina, sim.
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> 444"
# E óbvio... Não é para tomar sem receita ..
# Mas fake news é demais..
# passou na TV A imagem pode conter: 2 pessoas, pessoas em pé
# fake news da Luciana aí em cima... Dizendo que o caso da morte foi hj e foi a cloroquina que matou... Mas foi fosfato de cloroquina .. que é outra coisa ..
# aaah eu pensei que era sobre os pacientes.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Rs
# 👏 👏 👏 👏
# Não interessa o remédio que tomou.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> COMO UMA PESSOA PODE TOMAR UM REMÉDIO SEM.ESTAR DOENTE????????????
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Se não morrer do vírus morre por ser hipocondríaco.
# Sentiment(polarity=-0.09090909090909091, subjectivity=0.7386363636363636) ==> mas não tomaram remédio... Fosfato de cloroquina é para limpar aquário kkkk
# 😂 😂 😂 😂 😂 😂 😂 😂 misericórdia senhor 😂 😂 😂 😂
# pois é ... Tem louco para tudo kkkk
# Kkkk
# tenho quse a certeza que è fake new mas vou investigar,
# não é fake não, passou na TV A imagem pode conter: 2 pessoas, pessoas em pé
# ok,
# ,torcendo que de certo 🙏
# Passou nos jornais, não é falsa a notícia.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# A imagem pode conter: texto que diz "19:34 1,2KB/s Hidroxicloroquina: qu... .com.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 口 Gabriela Ingrid VivaBem, em São Paulo 26/03/2020 15h01 Pelo menos quatro que estavam na UTI em estado grave no Hospital Igesp, em Sao Paulo, receberam alta após sete dias de USo de hidroxicloroquina em associação com outras medicações.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> De acordo com Dante Senra, médico cardiologista coordenador das UTI's do hospital, foram "avaliados criteriosamente os protocolos internacionais" 12 altas hospitalares de pacientes confirmados com coronavírus altamente suspeitos também foram dadas.
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> Instalar MELHORES HORES JOGAM x"
# FAKE
# A imagem pode conter: 2 pessoas, pessoas em pé
# o senhor está me acusando de difundir notícias falsas em uma postagem pública?
# Sentiment(polarity=0.0, subjectivity=0.25) ==> O senhor sabe que me está causando um dano moral?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É que é crime acusar alguém sem provas?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Caso o senhor não se retrate publicamente terei que tomar as medidas cabíveis.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Obrigado.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Mete processo nesse cara., já printei se precisar.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> me manda a fonte 🙏 🙏 🙏 que Deus nos ajude ❤ ❤ ❤ vamos vencer 💪 💪 💪
# ministério da saúde.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> obg querido viu ver agoraaaaaa isso é mta emoção
# Não é fake.… Ver mais Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Os próprios médicos deram entrevista confirmando.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E quem ja teve o virus corona!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> !pode pegar de novo sera???
# Sentiment(polarity=0.0, subjectivity=0.0) ==> sim!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Esse é uma mutação.
# Sentiment(polarity=-1.0, subjectivity=1.0) ==> Ninguém tem anticorpos pra ele
# Imagina pegar 2 ou 3 vezes Deus me livre
# geralmente, mesmo sendo uma mutação o RNA base é o mesmo, então, se a pessoa não tem severos problemas de saúde, os sintomas são ainda mais brandos
# Esse virus agente tem mil e uma duvidad amiga!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> !obrigada
# existem casos q reincidência sim.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não se sabe, se contraíram novamente ou o vírus ainda estava no organismo.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Por ser um vírus totalmente novo, estão estudando todas as possibilidades possíveis
# Precisamos muito ums dos outros e se unir pra acabar com a peste
# 🙏🏻 🙏🏻
# 90% das pessoas nunca ouviram falar desse medicamento, agora várias pessoas são especialistas no assunto?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> "SE TOMAR MORRE!"
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 😂 "TA MATANDO , TA MATANDO" "AGE DE FORMA DIFERENTE EM CADA ORGANISMO" Só groselha... Faço uso continuo há anos do medicamento, nunca ouvi falar que "matou" alguém 👍 O uso tem que ser feito com acompanhamento médico, a gramagem do remédio é alta, de forma alguma pode se auto medicar com ele.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> #NãoFaleGroselhaSemSaber Pergunte para quem usa, ou para quem entende da medicação 👍 A imagem pode conter: texto que diz "Reuquinol® sulfato de hidroxicloroquina 400 mg COMPRIMIDOS REVESTIDOS USO ADULTO PEDIATRICO USO ORAL CONTÉM: 30 COMPRIMIDOS"
# Deus seja louvado
# Mentira!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Esse remédio é proibido e tem efeito colateral ...
# Não é mentira 👍
# A imagem pode conter: 2 pessoas, pessoas em pé
# É verdade foi anunciado ontem pelo ministerio da saúde, porem Só pode ser usado nos hospitais cm médicos
# não é mentira
# Não é mentira!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pausar GIF GIPHY
# É verdade, o ministro da saúde falou sobre ontem e hoje foi falado na Record!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> não acuse sem provas, isso é crime.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Usado em nível hospitalar, em dosagem certa, ele pode trazer resultado sim.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não é mentira.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ele se tornou controlado, pq, realmente tem efeitos colaterais e pode ser tóxico se tomar errado.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E um medicamento para malária, pactes com reumatismo e ludipus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Infelizmente qdo saiu na mídia q ele poderia "curar" o covid esses pactes, de uso contínuo, ficaram sem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> A Anvisa agiu rápido e colocou ele no controle especial duplado.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Mas ele tem efeito positivo sim, sob os pactes graves de COVID-19.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É só ler, estudar, se informar.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Custa nada não.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> é médica?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> mentira é o que vc está dizendo, minha mãe tomou por 10 anos e não teve nenhum efeito colateral
# pesquise antes de dizer que é mentira.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# 🙏 🙏 🙏
# O brasileiro será cobaia para o mundo 🙁
# Fala que é verdade ❤
# Tomara
# Glória a Deus
# No jornal nacional comunista,só fala de mortes do corona é nenhum curado
# então, mas graças a Deus temos mtos
# Fonte?
# Sentiment(polarity=-0.5, subjectivity=1.0) ==> basta vc deixar de vê a globo e seus Jornais mequetrefe
# Fake News
# não é fake https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Não é cloroquina, é a hidroxicloroquina com azitromicina, mesmo assim estou bastante esperançosa...
# sim e associado com azitromicina.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Tbm estou esperançosa 🙏
# os próximos dez dias vão nos mostrar... Ainda que não seja a cura, se for um alívio, se impedir os pacientes de morrer ou de evoluir pra algo grave, já nos ajudará a enfrentar esse mal...
# vdd, vamos torcer 🙏
# Esse remédio será nossa esperança ❤ 🙏
# Passa a fonte p gente
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Amém
# Esse é o remédio pra cura do coronavírus e é fabricado no Brasil 🇧🇷 eu conheço esse remédio é pra quem tem lupo
# A imagem pode conter: uma ou mais pessoas
# Mentira!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> não
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Entrevista agora com a paciente na Record.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Vdd
# Todo mundo que comentou nesse post nao vai pegar o virus em nome de jesus
# Amém
# nao se preocupa amigo Deus esta com nos durna tranquilo
# Pra quem não acredita!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pesquisem!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Isso é fato pois confirmei com profissionais do hospital!!
# Sentiment(polarity=-0.15, subjectivity=0.2) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Notícias ruins galera aplaude, notícias boas dizem ser mentira.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> isso acontece muito é inacreditável
# eu não pretendo bater palmas e nem parabenizar o governo por nada.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> No meu ponto de vista, independentemente de quem quer q seja o governante, está fazendo OBRIGAÇÃO e não FAVOR.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> FEZ ERRADO EU COBRO … Ver mais
# ninguém tá falando de política.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos falando de medicina e cura
# negatividade e essa jovem.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Estamos falando de cura, a esperança de qualquer profissão e ser humano, foda se política, todo mundo tem que ser grato por qualquer profissão, antes e depois do corona.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Dias melhores virao, seja grato!
# Sentiment(polarity=-0.3875, subjectivity=0.4375) ==> Tudo coloca política no meio, aff 🤨
# Gloeia a DEUS
# https://www.otempo.com.br/interessa/saude-e-ciencia/covid-19-chineses-concluem-que-hidroxicloroquina-nao-e-melhor-que-cuidado-usual-1.2316343 Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual OTEMPO.COM.BR Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual
# esse estudo foi só com a hidroxicloroquina, sem o antibiótico, na verdade muito paciente deve piorar por conta de infecção secundária bacteriana, além de que a azitromicina tem efeitos anti-inflamatórios que podem ajudar na resposta inflamatória pulmonar... De qualquer forma, saberemos logo do potencial ou não já que o mundo inteiro está usando agora, a partir de ontem basicamente muitos estudos começaram...
# o risco dessas noticias com a cloroquina como cura é exatamente esse de fazer as pessoas usarem sem entender como funciona ou sem base e critério, e causar casos como esse: https://oglobo.globo.com/sociedade/coronavirus-homem-morre-mulher-internada-nos-eua-apos-tomarem-cloroquina-24325000 Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina OGLOBO.GLOBO.COM Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina
# tem que tomar muito cuidado com isso..
# Automedicação no geral é algo perigoso, na verdade
# Já foi liberada nós hospitais ...vocês só bosta pessimistas querem ver as coisas dado errado nem consegui ficar feliz notícias boa
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/25/cloroquina-cuidados-basicos-coronavirus.htm Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo NOTICIAS.UOL.COM.BR Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo
# https://gizmodo.uol.com.br/estudo-nao-encontra-evidencias-hidroxicloroquina-coronavirus/ Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil GIZMODO.UOL.COM.BR Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil
# https://oglobo.globo.com/sociedade/coronavirus-homem-morre-mulher-internada-nos-eua-apos-tomarem-cloroquina-24325000 Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina OGLOBO.GLOBO.COM Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina
# cloroquina de tanque de Aquário, por favor, neste momento pode não apoiar mas seja isento... Eu estou esperançosa mas isenta
# vc acha q eles cometeram essa imprudencia imbecil porque?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Porque a mídia espalhou a cloroquina como cura mágica... tem que ter muito cuidado com essas notícias, por isso, espalhar o nome do remédio nesse estagio da pesquisa ainda, é muito perigoso...
# Não sou contra a Cloroquina, só acho que temos que ter responsabilidade...
# concordo plenamente com você!
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5) ==> As pessoas precisam ser mais responsáveis em divulgar as coisas mas não temos controle, agora a mídia tem que informar de maneira assertiva... Os presidentes sem noção também tem... Eu sou farmacêutica, no meu ciclo eu aconselho a todos a aguardar, ainda não há dados... Mas quero ter esperança... Ao menos por enquanto, depois quero dados científicos, o quanto antes... Dez dias no máximo...
# tem ver na globo ..essa página.. pessimistas querem ver só lado errado tudo dando errado eu em
# fishfull think não ajuda nessas horas... sei que não podemo entrar em pânico, mas é importante entender a dimensão do caso, e ter responsabilidade diante de curas não testadas...
# Em alguns casos a cloroquina pode sim ser a cura, mas a dose é tão alta que tem que ser feita somente no hospital com médicos por perto porque se não souber administrar os efeitos colaterais são: arritmia cardíaca, infarto entre outras coisas relacionadas, então tomar muito cuidado com o que saem postando os desavisados podem sair usando de qualquer maneira e não pode
# Não é bem assim, vejam o que esse prof. explica sobre o assunto: https://youtu.be/raYslxs_VrY Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5) ==> YOUTUBE.COM Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5) ==> Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Entrevista agora com a paciente na Record.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Vdd
# Está funcionando no mundo todo, um alívio para todos
# Isso, divulga!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É somente com prescrição médica!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pode causar males também, se tomar por conta própria sabia?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 1
# Q bom graças a Deus
# Graças a Deus 💖 🙌
# ALELUIA
#
# #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao
# o Bolsonaro inventou esse remédio ?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> kkkkk gado e f... msm acredita ate que o bozo criou o remedio e tambem a cura kkkkkk
# TEU CÚ
# , Claro que não.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Esta sendo testado em todo o mundo.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> (TESTE DE UM MEDICAMENTO A MUITO TEMPO NO MERCADO).
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É bom que funcione .
# Sentiment(polarity=0.0, subjectivity=0.0) ==> respeito bozo
# Bolsominion burro!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> TEU CÚ TAMBÉM
# Merece respeito quem sabe respeitar.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Não respeitou?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Então vai tomar no CÚ
# não Vadia, mas enquanto todos são contra o uso do remédio ele mandou produzir e pesquisar sobre a eficácia
# Não funciona.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Li sobre o estudo feito na Itália.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E apenas um placebo para acalmar a população.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> … Ver mais
# Aonde vc viu isso?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> querida leia, desliga a Globo e vai ler está muito desinformada
# O estudo nem foi feito na Itália, foi na França...
# Primeiro que a dose de cloroquina é muito alta só deve ser feita no hospital pois se não o fizer corretamente se não morrer com o vírus morre de infarto e outros malefícios do próprio remedio
# Tambem deixou gente morta, entao, deixem para profissionais fazerem os testes, nao saiam por ai esgotando as farmacias, alem de estarem correndo riscos, esta tirando de quem realmente precisa
# já foi racionado justamente porque brasileiro não tem bom senso.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Agora só se compra com receita médica!
# Sentiment(polarity=0.375, subjectivity=0.5) ==> e lamentável
# Aqui em Santa Catarina a primeira morte contabilizada por corona vírus, o senhor de idade já estava doente a mais de um mês, um familiar mandou áudio avisando.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Ele ia e vinha do hospital, desenganado pelos médicos.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Numa dessas idas deve ter pego o vírus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Mas não fizeram nenhum exame pra saber.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Simplesmente foi considerada a primeira morte do Estado.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> É um absurdo, estão espalhando pânico!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> fontes Mauricio?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fontes?
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pq não acredito
# - nunca tem fonte!!
# Sentiment(polarity=0.1796875, subjectivity=0.5) ==> Menos que alguem tenha sido curado que e bom, teve gente morrendo, entao o uso de remedios nao controlados, deixem so ao o uso de medicos eles sabem o que fazem
# https://youtu.be/zF2pXXJIAGM Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias YOUTUBE.COM Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias
# Comparativo BRASIL X ITÁLIA ITALIA 14X + MORTES… Ver mais 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> YOUTUBE.COM 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Pra quem não acredita, basta assistir o programa do Datena hoje.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Datena não é confiável
# Glória a Deus
# Não demora muito e a #GloboLixo começa a condenar esse remédio....
# Vc é um bolsominion burrão!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> , calma, o carrinho com o pão com mortadela já passa pela tua rua.... 🤣 🤣 🤣 🤣 🤣
# Vc é um completo idiota!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Odeio tanto os adoradores do Luladrão como os imbecis como vc, que não ouvem as autoridades médicas, os infectologistas e sim o Bozo tresloucado!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Parem de politizar isso, nessa hora tem esquerda e nem direita bando de imbecil
# Bando de jumentos A imagem pode conter: texto que diz "Lula Livre!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Bolsonaro mito!"
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Segundo eu li em uma postagem (Não me lembro onde) cloroquina +azitromicina=cura
# Em Milão eles ainda não sabiam da virulência tão trágica do novo coronavírus.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Nós agora sabemos!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E é bem forte esta Palavra de Deus: "... Eu lhes propus a vida ou a morte, a bênção ou a maldição.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Escolha, portanto, a vida, para que você e seus descende… Ver mais
# A imagem pode conter: atividades ao ar livre, texto que diz "CARREATA NA ITÁLIA DEPOIS DA LIBERAÇAO DO COMERCIO COM @DOUGLASREZENDEPSOL 니 ADENN PHARMACIE CAMINHÕES DO EXÉRCITO COM CAIXOES LAUTADOS"
# Conheço uma pessoa com asma Que teve , foi 3 vezes no hospital , por fim detectaram pneumonia Mas ela está curada … Ver mais
# ????
# Sentiment(polarity=0.0, subjectivity=0.0) ==> não consegui saber o remédio q foi usado
# DIÓXIDO DE CLORO - CLO2 - MMS "O dióxido de cloro é registrado na Agência de Proteção Ambiental dos Estados Unidos (EPA) como desinfetante, desinfetante e esterilizador, definido como a capacidade" de destruir ou eliminar todas as formas de vida microbiana, incluindo fungos, vírus e todas as formas de bactérias e seus esporos ".
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Abaixo estão alguns dos organismos mais comumente vistos que o Dióxido de Cloro foi eliminado.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Até o momento, nenhum organismo testado contra o Dióxido de Cloro provou ser resistente."
# Sentiment(polarity=0.0, subjectivity=0.0) ==> E o coronavírus está na lista E vírus corona da Síndrome Respiratória Aguda Grave (SARS)!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Créditos Scott M https://drive.google.com/file/d/1Jqqr1qMWBZz8OGDJsbV84BJzAaahaDIX/view?usp=drivesdk Chlorine dioxide registered as a biocide by EPA.pdf DRIVE.GOOGLE.COM Chlorine dioxide registered as a biocide by EPA.pdf Chlorine dioxide registered as a biocide by EPA.pdf
# Porque a gente gosta de números!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Leiam com atenção.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> "A leitura desse texto é extremamente importante para que se entenda de uma vez que isso não é “gripizinha” e ações de supressão precoce farão toda a diferença!!
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Fonte: ProEpi - Associação Brasileira de Profissionais de Epidemiologia de Campo “Saiu a modelagem estatística do Imperial College London para os cenários do COVID-19 no Brasil.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Antes, uma introdução.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> No começo da pandemia o governo do Reino Unido havia decidido apostar em uma estratégia de “imunidade de massa”, que consistia em não tomar medidas restritivas; em vez de parar o país, deixariam que o vírus infectasse a população de modo que rapidamente as pessoas pudessem ficar imunizadas.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Porém, o governo do Reino Unido desistiu dessa ideia quando uma equipe de especialistas epidemiológicos do Imperial College of London apresentou uma previsão de como se desenrolaria a disseminação do COVID-19 em diferentes cenários de contenção para o Reino Unido e para os Estados Unidos.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Para elaborar essa previsão, utilizaram dados de contágio, estatísticas de hospitalização e óbitos vistos em outros países, estudaram como o vírus se dissemina em diferentes ambientes etc.. Como um breve resumo: se circular livremente, o vírus tem a capacidade de infectar cerca de 80% da população geral em um período muito curto.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Das pessoas infectadas, cerca de 20% precisam de hospitalização, 5% dos casos são críticos e precisam de UTI e suporte respiratório, e cerca de metade dos casos críticos vêm a óbito.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> No entanto, o súbito aumento de casos ultrapassa a capacidade do sistema de saúde, gerando colapso, e disso resulta um número muito maior de mortes — de covid-19, assim como de outras causas — simplesmente porque não há hospital para tratar todas as pessoas que precisam.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Segundo a previsão, se não houver restrições nos contatos, no mundo inteiro seriam 7 bilhões de pessoas infectadas com covid-19 e 40 milhões de mortes neste ano.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Os números previstos por esses estudos fizeram com que governos desistissem das posturas mais relaxadas e tomassem as medidas mais restritivas para evitar o colapso do sistema de saúde e um número muito maior de mortes.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> # Ontem, no dia 26/03/2020, o Imperial College of London soltou números previstos para os desfechos da pandemia em todos os países, nos cenários sem intervenção, com mitigação, e com supressão.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Mitigação envolve proteger os idosos (reduzir 60% dos contatos) e restringir apenas 40% dos contatos do restante da população.
# Sentiment(polarity=0.03333333333333333, subjectivity=0.06666666666666667) ==> Supressão envolve testar e isolar os casos positivos, e estabelecer distanciamento social para toda a população.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Supressão precoce – implementada em uma fase em que há 0,2 mortes por 100.000 habitantes por semana e mantida Supressão tardia – implementada quando há 1,6 mortes por 100.000 habitantes por semana e mantida.
# Sentiment(polarity=-0.18333333333333335, subjectivity=0.4708333333333333) ==> # No Brasil os cenários previstos são os seguintes: Cenário 1- Sem medidas de mitigação: - População total: 212.559.409 - População infectada: 187.799.806 - Mortes: 1.152.283 - Indivíduos necessitando hospitalização: 6.206.514 - Indivíduos necessitando UTI: 1.527.536 # Cenário 2 - Com distanciamento social de toda a população: - População infectada: 122.025.818 - Mortes: 627.047 - Indivíduos necessitando hospitalização: 3.496.359 - Indivíduos necessitando UTI: 831.381 # Cenário 3 - Com distanciamento social E REFORÇO do distanciamento dos idosos: - População infectada: 120.836.850 - Mortes: 529.779 - Indivíduos necessitando hospitalização: 3.222.096 - Indivíduos necessitando UTI: 702.497 # Cenário 4 – Com supressão tardia - População infectada: 49.599.016 - Mortes: 206.087 - Indivíduos necessitando hospitalização: 1.182.457 - Indivíduos necessitando UTI: 460.361 - Demanda por hospitalização no pico da pandemia: 460.361 - Demanda por leitos de UTI no pico da pandemia: 97.044 # Cenário 5 – Com supressão precoce - População infectada: 11.457.197 - Mortes: 44.212 - Indivíduos necessitando hospitalização: 250.182 - Indivíduos necessitando UTI: 57.423 - Demanda por hospitalização no pico da pandemia: 72.398 - Demanda por leitos de UTI no pico da pandemia: 15.432 # Faço algumas observações: Os próprios autores do estudo comentam que modelaram essas curvas com base nos padrões de dispersão dos países ricos e que nos países pobres os resultados da pandemia podem ser piores do que o previsto.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> Esses números previstos não levam em conta a existência de favelas, comunidades sem abastecimento de água e/ou saneamento, entre outros complicadores que temos no Brasil.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> # É preciso comentar que os números reais da pandemia no Brasil, seus casos e óbitos, estarão amplamente subnotificados devido à falta de testes e demora nos resultados.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> As estatísticas oficiais publicadas pelo Ministério da Saúde mostrarão apenas a ponta do iceberg.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> # Mesmo nos melhores cenários, lentificando a transmissão e aumentando os recursos do sistema de saúde, deve faltar UTI e respirador para parte dos doentes.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> # Em resumo, a diferença entre ficarmos todos em casa (supressão) ou adotar uma estratégia mais branda de mitigação e proteção apenas dos grupos de risco pode ser da ordem de MEIO MILHÃO de vidas.
# Sentiment(polarity=0.0, subjectivity=0.0) ==> # Os diversos relatórios estão disponíveis no site do Imperial College of London: https://www.imperial.ac.uk/mrc-global-infectious-disease-analysis/news--wuhan-coronavirus/?fbclid=IwAR0GeexFNu6ezOVclPBVW5x3Z3yOn5N1X6siDO5P7ezUOm_UwOUu31RBoAY Link para o trabalho “The Global Impact of COVID-19 and Strategies for Mitigation and Suppression”: https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/Imperial-College-COVID19-Global-Impact-26-03-2020.pdf As tabelas com os números oferecidos constam no apêndice: https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/Imperial-College-COVID19-Global-unmitigated-mitigated-suppression-scenarios.xlsx “ IMPERIAL.AC.UK COVID-19 reports COVID-19 reports
# Esse remédio curou a malária (leiam no Google,sobre essa...) Cientistas vão misturar , testar , várias fórmulas...

# %% [markdown]
# ## Analisadores estatísticos
# É por causa disso que os modelos estatísticos talvez sejam uma solução melhor pro nosso problema do que simplesmente desistir da pesquisa por não termos recursos em língua portuguesa. Notável a diferença entre os resultados de ambos os analisadores, um deles o padrão do TextBlob e o outro usando o algoritmo Naive-Bayes.

# %%
# a ferramenta crua, sem nenhum parâmetro: Sentiment(polarity=-0.30575317614006275, subjectivity=0.6938446969696971)
teste1.sentiment
# Out:
# Sentiment(polarity=-0.30575317614006275, subjectivity=0.6938446969696971)

# %%
# usando o analisador Naive Bayes do NLTK
import nltk
nltk.download('movie_reviews')
nltk.download('punkt')

from textblob.sentiments import NaiveBayesAnalyzer

teste1 = TextBlob(data1, analyzer=NaiveBayesAnalyzer())
teste1.sentiment
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Sentiment(classification='pos', p_pos=0.9999978271912772, p_neg=2.1728087504764657e-06)

# %% [markdown]
# Os exemplos citados logo mais mostram como a atuação desse analisador é um pouco questionável, pelo menos nessa implementação específica. As palavras "odeio" e "imbecis" não fizeram nem cócegas no resultado da avaliação, positiva. Enquanto isso, um outro comentário cheio de palavras de conotação negativa, mas classificado manualmente como neutro, tem alta polaridade positiva na avaliação de sentimento:
#
# ```
# Sentiment(classification='pos', p_pos=0.833333333333333, p_neg=0.16666666666666646) ==> Odeio tanto os adoradores do Luladrão como os imbecis como vc, que não ouvem as autoridades médicas, os infectologistas e sim o Bozo tresloucado!!
# Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334) ==> Das pessoas infectadas, cerca de 20% precisam de hospitalização, 5% dos casos são críticos e precisam de UTI e suporte respiratório, e cerca de metade dos casos críticos vêm a óbito.
# ```
#
# Observando os seus resultados, não sei se dá pra dizer qual deles foi melhor porque ambos parecem ter se saído meio mal quando a gente analisa linha a linha. Uma das dependências que esse analisador usa para funcionar é um _corpus_ de avaliação de filmes, provavelmente também em língua inglesa. Talvez seja uma boa ideia criar nosso próprio classificador.

# %%
# agora, linha a linha
teste1 = TextBlob(data1, analyzer=NaiveBayesAnalyzer())

# essa função pega o dataset e exibe sentimento linha a linha. Ou pelo menos tenta. :-/
def sent(data):
  for sentence in data.sentences:
    print(sentence.sentiment, '==>', sentence)

sent(teste1)
# Out:
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Conteúdo
# Os casos eram graves ?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Estavam com respiradores?
# Sentiment(classification='neg', p_pos=0.3749999999999995, p_neg=0.6249999999999998) ==> Ac
# Somente casos graves estão usando cloroquina
# Up
# Glória à Deus!
# Sentiment(classification='pos', p_pos=0.5357142857142863, p_neg=0.46428571428571397) ==> Ac
# Gloria a Deus ❤️
#
# Deus e maravilho
# Amém
# Amém!!!
# Sentiment(classification='pos', p_pos=0.5078125, p_neg=0.4921875000000001) ==> Que continue dando certo a todos
# Tomara
# Isso não é nem perto de ser a solução
# Para de pensar negativo.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Por isso que o brasil nao vai pra frente
# Amém 🙏
# Deve ser Feike!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 1
# Não é.
# Sentiment(classification='neg', p_pos=0.48214285714285715, p_neg=0.5178571428571429) ==> 75 anos, estava em estado grave e já tinha até se despedido da família.
# Sentiment(classification='neg', p_pos=0.28229774748616854, p_neg=0.7177022525138299) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/22/mae-de-donos-da-prevent-senior-e-tratada-com-cloroquina-temos-esperanca.htm Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança" UOL.COM.BR Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança" Mãe de donos da Prevent Senior é tratada com cloroquina: "Temos esperança"
# difícilmente ele irá postar algo fake.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Para de pensar negativo.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Por isso que o brasil nao vai pra frente 1
# Isso para quem consegue comprovar que tem o vírus.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 🙏🏼 🙏🏼 🙏🏼
# Lembrando que não é só o uso de cloroquina
# É em conjunto com a Azitromicina.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> e um coquetel junto com.
# Sentiment(classification='pos', p_pos=0.5434782608695657, p_neg=0.45652173913043487) ==> Oxacilina, rinfanpricina
# só tem uma coisa se eu ficar nessa situação morrendo sem ar tomem essa atitude comigo mesmo com todos os efeitos colaterais que tiver!
# Sentiment(classification='neg', p_pos=0.16666666666666688, p_neg=0.833333333333334) ==> Se formos ler bula não nos tratamos para nada tudo tem ou pode ter efeito colateral
#
# Amém 🙏
# Amém Deus todo poderoso que está no meio de nós ❤️ 🙏
# Glória Deus
# Onde vc viu isso pra Amim compartilhar?
# Sentiment(classification='neg', p_pos=0.25000000000000033, p_neg=0.75) ==> Q seja verdade e q acabe logo com isso!!
# Sentiment(classification='neg', p_pos=0.3823529411764708, p_neg=0.6176470588235293) ==> Deus nos abençoe
# Datena
# 🙏 🙏 🙏 🙏 graças a deus tomara que continue assim
# Para de passar informação errada galera.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> A cloroquina precisa ser associada com todo um protocolo de tratamento.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Aí vem os imbecil que nem doente está e sai comprando, deixando quem depende do medicamento sem.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> falaram que agora somente pode comprar com permissão de um médico
# Ta certo
# tomara que as drogarias sigam as instruções!
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> mas por enquanto é só para quem está muito ruim para casos leves ou prevenção não precisa!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> O problema é que o pessoal não entende isso!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Já saiu inclusive várias reportagens sobre o fato da galera estar comprando sem necessidades.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 🙏
#
# Tomara q seja verdade.
# Sentiment(classification='neg', p_pos=0.14655172413793166, p_neg=0.853448275862068) ==> Amem
# Não adianta nada ele hospedeiro intermediário sintomas acabam mas ele passa a doença
# acho que não hein Quando a pessoa fica em alta e porque ja foi curada Esta sem o virus no corpo
# vírus sofre mutação se ela esta imune ela pessoa mas perigosa porque ela não vai ter mas sintomas só passa a doença.
# Sentiment(classification='pos', p_pos=0.6197916666666664, p_neg=0.38020833333333254) ==> acredito que não Não ouvi ninguém falar isso Quando o infectado e curado pode sim pegar novamente se não se prevenir Mas o virus desaparece No mundo todo já são mais de 100 mil curados
# Povo querido cuidado com estas informações.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Nao tome medicamentos sem prescricao médica.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Datena e batti
# Tá passando tv
# meus amores sou enfermeira com pós em emergência e UTI.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não faça isso.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Ainda não temos comprovações que realmente ele é eficaz contra o vírus.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Estamos lutando diariamente contra s morte.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Estamos preocupados com todos.
# Sentiment(classification='pos', p_pos=0.7000000000000001, p_neg=0.3000000000000001) ==> Estamos lutando o tempo todo .
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Nos ajudem.
# Sentiment(classification='neg', p_pos=0.0625, p_neg=0.9374999999999983) ==> Beijos
# Graças à Deus 🙏🏻
# A imagem pode conter: 1 pessoa, texto que diz "cartunistamachado ODEBATE DO SÉCULO DESTE LADO DO RINGUE ELE, CIENTISTA, PHD, POS GRADUADO PELA SOURBONNE... E DESTE LADO o DESAFIANTE COM SUA OMSUA CONTA NO FACEBOOK!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> macrads."
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> Gente isso é verdade,Glória Deus.
# Sentiment(classification='pos', p_pos=0.7306232861483712, p_neg=0.26937671385162737) ==> Amém mas não devemos acabar com os estoques, devemos deixar para quem realmente vai precisar
# Poxa uma notícia maravilhosa dessas e o que tem de comentários negativos por aqui.. parece que só gostam de notícias ruins .. Que muitas outras pessoas tenham altas ... ❤️
# Tomare não seja mentira aqui na Net tá saindo muitas notícias falsas Se for vdd que Deus nos ajude
# Amém no Amapá tb estão usando
# Se for verdade mesmo, que Deus nos ajude !
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> é verdade simmm
# Glória a Deus !
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> A imagem pode conter: uma ou mais pessoas
# Isso é sério!
# Sentiment(classification='neg', p_pos=0.17966856273043177, p_neg=0.8203314372695684) ==> Poxa não vamos passar notícias falsas não por favor esse momento de medo e dor..
#
# glória a Deus começaram a aparecer boas notícias que assim continue 👏🏻 👏🏻 🙏🏼 🙏🏼 🙏🏼
#
# Isso sim é uma boa notícia 👏 👏 👏 👏
# Será verdade espero q sim m n vi nada vinda do governo...se for mesmo saberemos logo
# ISSO É QUE NEM ESTAMOS NO PICO E JÁ TEM GENTE DESESPERADO
# Graças a Deus 💞
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# eu tava lendo a bula mas não entendi muito bem, os efeitos colaterais desse remédio me corrijam e me desculpem se eu estiver errada mas os efeitos colaterais não pareceu tão graves, E se não for porque não ultilizar em quem estiver prescisando?
# Sentiment(classification='neg', p_pos=0.38235294117647034, p_neg=0.6176470588235293) ==> estão usando como protocolo em pacientes graves... Junto com outros medicamentos..
# hum entendi obrigada
# Pode passar a fonte?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> https://istoe.com.br/quatro-pacientes-de-uti-com-coronavirus-tem-alta-apos-uso-de-hidroxicloroquina/ Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente ISTOE.COM.BR Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente
# obrigado!
# Sentiment(classification='pos', p_pos=0.6428571428571421, p_neg=0.35714285714285665) ==> Vai dar certo fe em Deus.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Esse remédio só está sendo usado em pacientes que estão na uti com acompanhamento médico e autorização da familia.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Ainda está em análise.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Nas farmácias so vende por intermédio de receitas.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Então quem tá com suspeita não vá atr… Ver mais
# eles usaram fosfato de cloroquina, utilizado para limpeza de aquário e não o hidroxicloroquina.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> na reportagem está hidróxicloroquina
# Então essa que você viu foi muito tendenciosa agindo de má fé, porque não foi hidroxicloroquina
# https://istoe.com.br/quatro-pacientes-de-uti-com-coronavirus-tem-alta-apos-uso-de-hidroxicloroquina/ Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente ISTOE.COM.BR Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente Quatro pacientes de UTI com coronavírus têm alta após uso de hidroxicloroquina - ISTOÉ Independente
# estou falando do casal que você citou, que tomou medicamento e o homem veio a falecer...
# entendi desculpe o casal foi cloraquina mesmo
# Fonte ?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> vai procurar, preguiça de gente preguiçosa.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> , tem gente torcendo contra, aff...pior que o próprio vírus ...
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# blza, achei
# Que maravilha!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Será que existe alguém com mais de 60 anos nesse grupo que se recuperou?
# Sentiment(classification='pos', p_pos=0.6262886597938153, p_neg=0.3737113402061858) ==> dizeram que tem um senhor de 75 anos que estava em estado grave e se despediu de sua familia acreditando que iria falecer Mas graças a Deus passa bem
# Datena mostrando o cientista!
# Sentiment(classification='pos', p_pos=0.525, p_neg=0.4750000000000001) ==> É verdade sim ,tá passando na Record agora,tô assistindo
# Caraca, não tem nem 24 horas que o ministério da saúde definiu o protocolo de uso da cloroquina e liberou o uso em pacientes graves e já tem gente curada?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> O remédio é bom demais.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> estava em off-label, já estava sendo usado a mais de uma semana...
# Aí sim, então pode ser verdade a notícia, que bom.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Rezar para não ter recaida.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Obrigado pela informação.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> kkkkkkkkkkkk Mas que foi engraçada a sua postagem, isso foi !!!
# Sentiment(classification='pos', p_pos=0.9206500956022948, p_neg=0.07934990439770535) ==> Eu tento não fazer isso mas as vezes escapa, é tanta notícia desencontrada que desanima
# Pior que quando eu li pensei exatamente a mesma coisa... Ai vi seu post e era o que eu ia postar kkkkk
# E vrd está passando no jornal !
# Sentiment(classification='pos', p_pos=0.6262886597938153, p_neg=0.3737113402061839) ==> A imagem pode conter: 1 pessoa, texto que diz "ப" H /PA PACIENTES TRATADOS COM CLOROQUINA RECEBEM ALTA DA UTI EM SÃO PAULO"
# Graças a Deus
# 4Altas e 1 morte e outra em estado grave devido a essa medicação, pesquisem direito .
# Sentiment(classification='neg', p_pos=0.48214285714285715, p_neg=0.5178571428571429) ==> O que morreu é a que está em estado grave tomou por conta própria não teve orientação médica!
# Sentiment(classification='pos', p_pos=0.5434782608695657, p_neg=0.45652173913043487) ==> no q vi , cada organismo tem uma reação, e por ser divulgado mtos já estao indo atrás da medicação pois a demora e a falta de exame faz com q isso aconteça, !
# Sentiment(classification='neg', p_pos=0.3504901960784314, p_neg=0.6495098039215692) ==> Mtos se auto medicam sem nem ir ao hospital, e agra mtos vão e são orientad… Ver mais
# concordo !
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Bom que agora não são todos que terão acesso , somente com receitas médicas.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> E daí .
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> O povo eim Graças a Deus pelos 4e antes que todos morriam !
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> a postagem é sobre os que tiveram alta .
# Sentiment(classification='pos', p_pos=0.7222222222222221, p_neg=0.27777777777777785) ==> Leia direito
# eu li , e tbm respondi oq tbm li !
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Apenas repassei oq vi , a respeito se puder ler meu texto e interpretar VC vai ver.
# Sentiment(classification='pos', p_pos=0.6428571428571421, p_neg=0.35714285714285665) ==> Glórias a DEUS 🙏🏻❤
# Está passando no R7 mas é incrível como tem gente negativa, aff!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Vamos torcer para que não tenha nenhum efeito após o uso.
# Sentiment(classification='pos', p_pos=0.5833333333333347, p_neg=0.416666666666667) ==> Eu na minha casa 🏠 Vc na sua casa 🏡 E Deus na casa de todos nós 🙏 🙏 🙏
# Vão esperar passar na globolixo?que nada,a única coisa que vão ouvir vai ser: Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,Bolsonaro,
# , vd
# ou então panelaço , panelaço
# ,panelaço gravado num pendriver
# esse panelaço e do tempo da Dilma ainda.... #globo lixo .
# Sentiment(classification='pos', p_pos=0.9247463296367785, p_neg=0.07525367036321991) ==> Estamos em vantagem ALQUEM tem q ser cobaia 0:00 / 0:02
# Noticia boa
# Mas não e para todos hello
# Senra explicou que os resultados não fazem parte da coalizão covid-19, feita pelo Hospital Israelita Albert Einstein, HCor, Sírio Libanês e BRICNet, uma rede que realiza estudos clínicos na área de medicina intensiva.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> O especialista ainda fez questão de ressaltar que não há comprovação de causa e efeito do uso da hidroxicloroquina.
# Sentiment(classification='pos', p_pos=0.6428571428571437, p_neg=0.35714285714285665) ==> Ou seja, não é possível garantir que os pacientes foram curados graças ao medicamento.... - Veja mais em https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm?cmpid=copiaecola Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# 🙏 🙏 🙏 🙏 🙏
# Graças a Deus
# Teve mais mas não falam
# Meu Deus..sera verdade??
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> ?.no meio desse caos..a gente nao sabe mais no que acreditar.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> , está passando no R7
# .....vou ver querida...obrigada
# A imagem pode conter: 2 pessoas, pessoas em pé
# Fontes?!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> vai procurar, preguiça de gente preguiçosa.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> ²
# O Dono da postagem é a fonte .
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> 👍 Ele sempre da notícias verdadeiras aqui
# kkkkk Hoje a música perdeu 2 pessoas para o Coronavirus.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Muito triste.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> , ah, nossa!
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> Se a pessoa faz uma postagem dessa, o certo é citar a fonte, né, não?!
# Sentiment(classification='pos', p_pos=0.525, p_neg=0.4750000000000001) ==> Não é questão de preguiça, é questão de lógica...
# Licença gente, foi noticiado agora pouco, nos jornais da rede Bandeirantes, e Record.
# Sentiment(classification='pos', p_pos=0.5681818181818187, p_neg=0.43181818181818143) ==> Na rede Record hj a noite passará uma reportagem exclusiva sobre o assunto.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> A informação é verídica 👍
# A imagem pode conter: 2 pessoas, pessoas em pé
# , obrigada!
# Sentiment(classification='pos', p_pos=0.6428571428571421, p_neg=0.35714285714285665) ==> M ♥️ ♥️ ♥️
# A mãe do meu compadre está na UTI e começou a usar esse medicamento ontem, hoje ela já teve melhora 🙏 🙏
# poste quando ela tiver alta, vamos nos animar e que Deus restaure a saúde e abençoe todos os doentes e acabe com a força desse vírus.
# Sentiment(classification='pos', p_pos=0.7812500000000012, p_neg=0.21874999999999967) ==> Amém
# postarei qndo ela tiver alta 🙏
# isso, porque ai temos mas uma esperança.
# Sentiment(classification='neg', p_pos=0.416666666666667, p_neg=0.5833333333333333) ==> Graças a Deus 🙏
# , é uma boa ideia !!
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> Graça à Deus Amém senhor 🙏 🙏 🙏
# No balanço geral de São Paulo está passando agora
# Olha ,sei que devemos ter cautela ,porém gente ,que benção está sendo ,pessoas curadas,pessoas que estão vencendo esse vírus!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.4999999999999988) ==> Que isso possa acontecer com todos os que pegarem o vírus ,vamos nos unir em oração ,para que tudo isso passe logo ,e as pesso… Ver mais
# Gente se liga nas notícias viu?
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> Este perfil é Fake!
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> O Facebook está lotado de perfis FAKE espalhando Fakenews!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Perfis sem fotos de família e de seus dias a dias e comentários algum!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Fiquem eapertos!
# Sentiment(classification='neg', p_pos=0.13920454545454547, p_neg=0.8607954545454544) ==> esse q postou a notícia se eu não me engano é quem criou essa página , ele sempre atualiza vários números e sempre da certinho
# Bom meu caro, a notícia não é fake.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Passou nos jornais, da rede Bandeirantes e no cidade alerta agora pouco.
# Sentiment(classification='pos', p_pos=0.5681818181818187, p_neg=0.43181818181818143) ==> Inclusive na Record hj passará uma reportagem especial sobre esse assunto 👍
# A notícia não é falsa.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# ta sobrando dinheiro para a indenização ou vai se desculpar?
# Sentiment(classification='pos', p_pos=0.7203389830508464, p_neg=0.2796610169491511) ==> Pausar GIF Tenor
# em quanto isso na minha cidade , o Corona Virus deve estar pulando d felicidade.
# Sentiment(classification='neg', p_pos=0.47938144329896887, p_neg=0.5206185567010309) ==> A imagem pode conter: texto que diz "TIM TIM 18:46 Pesquisar no Facebook 10 Amanhã vai ter protesto pedindo a reabertura do comércio em Presidente Prudente Ver mais PROTESTO PEDINDO ABERTURA DO COMÉRCIO EM PRESIDENTE PRUDENTE CONVITE COMERCIANTES, EMPRESÁRIOS.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> MOTOCICLISTA MOTORISTA TAXISTAS, TODOS TRABALHADORES UTÔNOMOS!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> \*EVENTO PACIFICO SEM FINS POLÍTICOS!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> VOLTA PRUDENTE!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 27/03 12H AV.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> CEL.
# Sentiment(classification='neg', p_pos=0.3365315346220479, p_neg=0.6634684653779515) ==> JOSÉ SOARES MARCONDES, PARTIDA EM FRENTE À APEA"
# mas nao quer dizer que estao curados,,,,,
# Dizem que o virus some do corpo do ex infectado Mas corre risco de pegar de novo se não se prevenir São mais de 100 mil curados no mundo todo
# Não existe comprovação da eficácia pela OMS
# exite sim só que oque acontece é qure fora do Brasil os médicos não são habilitados com o medicamento não sabendo a dosagem pois é pouco usado como no Brasil tem mais o uso foi liberado
# OMS é quem regula tudo!
# Sentiment(classification='neg', p_pos=0.3947368421052628, p_neg=0.6052631578947371) ==> OMS ja testou tudo q o Brasil usa e ainda vai usar.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> .
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Já testou sim se não fosse testa nem o ministério da saúde e nem a anvisa libera.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Só liberaram no Brasil porque os médicos conhecem o medicamento é a dosagem.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> A imagem pode conter: texto que diz "Atenção Usuário Facebook Gente se liga nas notícias viu?
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> Este perfil é Fake!
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> o Facebook está lotado de perfis FAKE espalhando Fakenews e afumentando o ódio entre pessoas!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Perfis sem fotos de família e de seus dia-a-dia nenhum comentário!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Fiquem espertos!"
# Sentiment(classification='pos', p_pos=0.7862903225806452, p_neg=0.21370967741935457) ==> Estava a 15 minutos, escutando o ministro da saúde é não falou nisso
# A imagem pode conter: 2 pessoas, pessoas em pé
# Lembrando que essa medicação é perigosa e só pode ser usada no hospital e administrada pela equipe médica no caso de corona.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Nada de se automedicar gente
# A imagem pode conter: texto que diz "Atenção Usuário Facebook Gente se liga nas notícias viu?
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> Este perfil é Fake!
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> o Facebook está lotado de perfis FAKE espalhando Fakenews e afumentando o ódio entre pessoas!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Perfis sem fotos de família e de seus dia-a-dia e nenhum comentário!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Fiquem espertos!"
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> a notícia não é falsa, passou nos jornais.
# Sentiment(classification='neg', p_pos=0.4283968413136121, p_neg=0.5716031586863882) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# A imagem pode conter: 2 pessoas, pessoas em pé
#
# A imagem pode conter: texto que diz "ALERTA PARA o MUNDO Economista do FMI que pedia fim da quarentena para salvar economia morre de coronavírus em Washington Rogério Correia"
# A imagem pode conter: 1 pessoa, texto que diz "17:30 https://www.metropoles.com/dis.. ETRÓPOLES Cofen Coren #EnfermagomContraCoronavirus DISTRITO FEDERAL Segurança de Bolsonaro está em estado grave com coronavírus "Ele sempre viaja com o presidente.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Eu acredito que esse vírus ele adquiriu nessas viagens' disse mãe do PM ao Metrópoles REPRODUÇÃO"
# Acabei de ficar sabendo q morreu foi gente tomando esse medicamento
# sem orientações de um médico
# Esse medicamento tem efeitos colaterais sérios, causa até cegueira
# https://www.covidvisualizer.com/?fbclid=IwAR2sRoHpl8GeEqr8A9ZyZ17hPGMmS4HH1q87fFFicm_eK0v9sRS5LGQSN68 COVID-19 Visualizer COVIDVISUALIZER.COM COVID-19 Visualizer COVID-19 Visualizer
# Nego enche o cu de cocaína, mas o que mata é minha cloroquina... Nenhuma descrição de foto disponível.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Tu sem lúpus?
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Tu tem corona?
# Sentiment(classification='pos', p_pos=0.7812500000000012, p_neg=0.21874999999999967) ==> Salvar um desconhecido de lupus com uma caixa, salvar 6 famíliares de corona com uma caixa, eis a questão.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não se automedique moça.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não sabe a posologia, não sabe os efeitos adversos, simplesmente você não sabe.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> eu vi
# Qual fonte?
# Sentiment(classification='neg', p_pos=0.25471698113207547, p_neg=0.7452830188679244) ==> passou na TV Band
# ok
# Passou nos jornais A imagem pode conter: 2 pessoas, pessoas em pé
# Vamos torcer e rezar para que esta pandemia acabe logo!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Temos que ter FÉ !!
# Sentiment(classification='neg', p_pos=0.25, p_neg=0.7500000000000009) ==> 🙏 🙏 🙏 🙏 👏 👏 👏 👏
# https://www.bbc.com/portuguese/brasil-52044400 Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França BBC.COM Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França Coronavírus: testes com cloroquina causam corrida a hospitais e dividem médicos na França
# Sabem como e Brasil ne, se consegue comprar remédios proibidos sabe se lá origem ... ficar espalhando essas notícias ajuda em nada.
# Sentiment(classification='neg', p_pos=0.32666666666666677, p_neg=0.6733333333333335) ==> É FAKE É FAKE É FAKE É FAKE É FAKE É FAKE
# A imagem pode conter: 1 pessoa, texto que diz "u!"
# Sentiment(classification='neg', p_pos=0.3266666666666664, p_neg=0.6733333333333335) ==> /P RECEBEM PACIENTES TRATADOS COM CLOROQUINA ALTA DA UTI EM SÃO PAULO"
# A imagem pode conter: 2 pessoas, pessoas em pé
# Não é fake.
# Sentiment(classification='pos', p_pos=0.5731707317073171, p_neg=0.4268292682926826) ==> Passou nos jornais A imagem pode conter: 2 pessoas, pessoas em pé
# acusar sem provas é crime e pode gerar uma indenização por danos morais.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Cuidado com as palavras em público.
# Sentiment(classification='neg', p_pos=0.3196626277801367, p_neg=0.6803373722198636) ==> propagar fake news é crime!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> deixa eles tomarem.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Vai ser bom p o Brasil 🤣 👍🏻
# TOMEM DESGRAÇA TOMEM!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 😅 😅 😅
# Gente.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> NAO TOMA ESSE REMÉDIO.
# Sentiment(classification='neg', p_pos=0.2901785714285711, p_neg=0.7098214285714285) ==> ele é para ser usado no hospital através do soro.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Tem um casal que morreu hoje por usar esse remédio em casa.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não sejam burros.
# Sentiment(classification='pos', p_pos=0.7410423452768731, p_neg=0.25895765472312643) ==> Remédio só se tiver doente.… Ver mais
# não foi hj e não foi cloroquina... Mas sim fosfato de cloroquina... É bem diferente... A imagem pode conter: texto que diz "TEXAS Homem morre após ingerir cloroquina, medicamento testado contra a Covid-19 Paciente tomou fosfato de cloroquina junto sua esposa, ainda está internada, hospital orte-americano orientou sobre os perigos da automedicação Por DA REDAÇÃO Ter, 24/03/20 08h38 520 09:50 Bernardo P Küster A mídia faz pânico hoje pois um casal morreu tomando cloroquina, potencial cura para vírus chinês.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> o eles contam APENAS FIM da reportagem é que casal tomou fosfato de cloroquina, usado para limpar aquários, e como prevenção.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Pap!!!
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> Como respeitar mídia, meu Deus!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> ganância.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Fosfato de cloroquina medicamento, a cloroquina, sim.
# Sentiment(classification='pos', p_pos=0.9457712942055294, p_neg=0.05422870579446836) ==> 444"
# E óbvio... Não é para tomar sem receita ..
# Mas fake news é demais..
# passou na TV A imagem pode conter: 2 pessoas, pessoas em pé
# fake news da Luciana aí em cima... Dizendo que o caso da morte foi hj e foi a cloroquina que matou... Mas foi fosfato de cloroquina .. que é outra coisa ..
# aaah eu pensei que era sobre os pacientes.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Rs
# 👏 👏 👏 👏
# Não interessa o remédio que tomou.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> COMO UMA PESSOA PODE TOMAR UM REMÉDIO SEM.ESTAR DOENTE????????????
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Se não morrer do vírus morre por ser hipocondríaco.
# Sentiment(classification='pos', p_pos=0.6255545558899265, p_neg=0.37444544411007274) ==> mas não tomaram remédio... Fosfato de cloroquina é para limpar aquário kkkk
# 😂 😂 😂 😂 😂 😂 😂 😂 misericórdia senhor 😂 😂 😂 😂
# pois é ... Tem louco para tudo kkkk
# Kkkk
# tenho quse a certeza que è fake new mas vou investigar,
# não é fake não, passou na TV A imagem pode conter: 2 pessoas, pessoas em pé
# ok,
# ,torcendo que de certo 🙏
# Passou nos jornais, não é falsa a notícia.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> A imagem pode conter: 2 pessoas, pessoas em pé
# A imagem pode conter: texto que diz "19:34 1,2KB/s Hidroxicloroquina: qu... .com.
# Sentiment(classification='pos', p_pos=0.8509503491078355, p_neg=0.1490496508921648) ==> 口 Gabriela Ingrid VivaBem, em São Paulo 26/03/2020 15h01 Pelo menos quatro que estavam na UTI em estado grave no Hospital Igesp, em Sao Paulo, receberam alta após sete dias de USo de hidroxicloroquina em associação com outras medicações.
# Sentiment(classification='pos', p_pos=0.9161139583961407, p_neg=0.0838860416038587) ==> De acordo com Dante Senra, médico cardiologista coordenador das UTI's do hospital, foram "avaliados criteriosamente os protocolos internacionais" 12 altas hospitalares de pacientes confirmados com coronavírus altamente suspeitos também foram dadas.
# Sentiment(classification='neg', p_pos=0.3661087866108789, p_neg=0.6338912133891212) ==> Instalar MELHORES HORES JOGAM x"
# FAKE
# A imagem pode conter: 2 pessoas, pessoas em pé
# o senhor está me acusando de difundir notícias falsas em uma postagem pública?
# Sentiment(classification='pos', p_pos=0.6397058823529416, p_neg=0.3602941176470587) ==> O senhor sabe que me está causando um dano moral?
# Sentiment(classification='pos', p_pos=0.5300751879699249, p_neg=0.46992481203007497) ==> É que é crime acusar alguém sem provas?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Caso o senhor não se retrate publicamente terei que tomar as medidas cabíveis.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Obrigado.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Mete processo nesse cara., já printei se precisar.
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> me manda a fonte 🙏 🙏 🙏 que Deus nos ajude ❤ ❤ ❤ vamos vencer 💪 💪 💪
# ministério da saúde.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> obg querido viu ver agoraaaaaa isso é mta emoção
# Não é fake.… Ver mais Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Os próprios médicos deram entrevista confirmando.
# Sentiment(classification='pos', p_pos=0.6071428571428579, p_neg=0.39285714285714224) ==> E quem ja teve o virus corona!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> !pode pegar de novo sera???
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> sim!
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> Esse é uma mutação.
# Sentiment(classification='neg', p_pos=0.13352782764811513, p_neg=0.8664721723518837) ==> Ninguém tem anticorpos pra ele
# Imagina pegar 2 ou 3 vezes Deus me livre
# geralmente, mesmo sendo uma mutação o RNA base é o mesmo, então, se a pessoa não tem severos problemas de saúde, os sintomas são ainda mais brandos
# Esse virus agente tem mil e uma duvidad amiga!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> !obrigada
# existem casos q reincidência sim.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não se sabe, se contraíram novamente ou o vírus ainda estava no organismo.
# Sentiment(classification='pos', p_pos=0.7857142857142845, p_neg=0.21428571428571433) ==> Por ser um vírus totalmente novo, estão estudando todas as possibilidades possíveis
# Precisamos muito ums dos outros e se unir pra acabar com a peste
# 🙏🏻 🙏🏻
# 90% das pessoas nunca ouviram falar desse medicamento, agora várias pessoas são especialistas no assunto?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> "SE TOMAR MORRE!"
# Sentiment(classification='neg', p_pos=0.20186023127199543, p_neg=0.7981397687280052) ==> 😂 "TA MATANDO , TA MATANDO" "AGE DE FORMA DIFERENTE EM CADA ORGANISMO" Só groselha... Faço uso continuo há anos do medicamento, nunca ouvi falar que "matou" alguém 👍 O uso tem que ser feito com acompanhamento médico, a gramagem do remédio é alta, de forma alguma pode se auto medicar com ele.
# Sentiment(classification='neg', p_pos=0.11199744735162692, p_neg=0.8880025526483725) ==> #NãoFaleGroselhaSemSaber Pergunte para quem usa, ou para quem entende da medicação 👍 A imagem pode conter: texto que diz "Reuquinol® sulfato de hidroxicloroquina 400 mg COMPRIMIDOS REVESTIDOS USO ADULTO PEDIATRICO USO ORAL CONTÉM: 30 COMPRIMIDOS"
# Deus seja louvado
# Mentira!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Esse remédio é proibido e tem efeito colateral ...
# Não é mentira 👍
# A imagem pode conter: 2 pessoas, pessoas em pé
# É verdade foi anunciado ontem pelo ministerio da saúde, porem Só pode ser usado nos hospitais cm médicos
# não é mentira
# Não é mentira!
# Sentiment(classification='neg', p_pos=0.26923076923076905, p_neg=0.7307692307692313) ==> Pausar GIF GIPHY
# É verdade, o ministro da saúde falou sobre ontem e hoje foi falado na Record!
# Sentiment(classification='pos', p_pos=0.5300751879699249, p_neg=0.46992481203007497) ==> não acuse sem provas, isso é crime.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Usado em nível hospitalar, em dosagem certa, ele pode trazer resultado sim.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não é mentira.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Ele se tornou controlado, pq, realmente tem efeitos colaterais e pode ser tóxico se tomar errado.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> E um medicamento para malária, pactes com reumatismo e ludipus.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Infelizmente qdo saiu na mídia q ele poderia "curar" o covid esses pactes, de uso contínuo, ficaram sem.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> A Anvisa agiu rápido e colocou ele no controle especial duplado.
# Sentiment(classification='neg', p_pos=0.25, p_neg=0.749999999999999) ==> Mas ele tem efeito positivo sim, sob os pactes graves de COVID-19.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> É só ler, estudar, se informar.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> Custa nada não.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> é médica?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> mentira é o que vc está dizendo, minha mãe tomou por 10 anos e não teve nenhum efeito colateral
# pesquise antes de dizer que é mentira.
# Sentiment(classification='pos', p_pos=0.8437500000000009, p_neg=0.15624999999999994) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# 🙏 🙏 🙏
# O brasileiro será cobaia para o mundo 🙁
# Fala que é verdade ❤
# Tomara
# Glória a Deus
# No jornal nacional comunista,só fala de mortes do corona é nenhum curado
# então, mas graças a Deus temos mtos
# Fonte?
# Sentiment(classification='neg', p_pos=0.2940553515955941, p_neg=0.7059446484044053) ==> basta vc deixar de vê a globo e seus Jornais mequetrefe
# Fake News
# não é fake https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Não é cloroquina, é a hidroxicloroquina com azitromicina, mesmo assim estou bastante esperançosa...
# sim e associado com azitromicina.
# Sentiment(classification='pos', p_pos=0.528293475725891, p_neg=0.4717065242741083) ==> Tbm estou esperançosa 🙏
# os próximos dez dias vão nos mostrar... Ainda que não seja a cura, se for um alívio, se impedir os pacientes de morrer ou de evoluir pra algo grave, já nos ajudará a enfrentar esse mal...
# vdd, vamos torcer 🙏
# Esse remédio será nossa esperança ❤ 🙏
# Passa a fonte p gente
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Amém
# Esse é o remédio pra cura do coronavírus e é fabricado no Brasil 🇧🇷 eu conheço esse remédio é pra quem tem lupo
# A imagem pode conter: uma ou mais pessoas
# Mentira!
# Sentiment(classification='pos', p_pos=0.525, p_neg=0.4750000000000001) ==> não
# https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Entrevista agora com a paciente na Record.
# Sentiment(classification='neg', p_pos=0.40891434262948334, p_neg=0.5910856573705175) ==> Vdd
# Todo mundo que comentou nesse post nao vai pegar o virus em nome de jesus
# Amém
# nao se preocupa amigo Deus esta com nos durna tranquilo
# Pra quem não acredita!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Pesquisem!!
# Sentiment(classification='pos', p_pos=0.5508474576271188, p_neg=0.4491525423728814) ==> Isso é fato pois confirmei com profissionais do hospital!!
# Sentiment(classification='neg', p_pos=0.4722222222222222, p_neg=0.5277777777777778) ==> https://www.uol.com.br/vivabem/noticias/redacao/2020/03/26/quatro-pacientes-de-uti-tiveram-alta-em-sp-com-uso-de-hidroxicloroquina.htm Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina UOL.COM.BR Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina Quatro pacientes de UTI tiveram alta em SP com uso de hidroxicloroquina
# Notícias ruins galera aplaude, notícias boas dizem ser mentira.
# Sentiment(classification='neg', p_pos=0.2499999999999997, p_neg=0.75) ==> isso acontece muito é inacreditável
# eu não pretendo bater palmas e nem parabenizar o governo por nada.
# Sentiment(classification='neg', p_pos=0.4687499999999998, p_neg=0.5312499999999999) ==> No meu ponto de vista, independentemente de quem quer q seja o governante, está fazendo OBRIGAÇÃO e não FAVOR.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> FEZ ERRADO EU COBRO … Ver mais
# ninguém tá falando de política.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Estamos falando de medicina e cura
# negatividade e essa jovem.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Estamos falando de cura, a esperança de qualquer profissão e ser humano, foda se política, todo mundo tem que ser grato por qualquer profissão, antes e depois do corona.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Dias melhores virao, seja grato!
# Sentiment(classification='neg', p_pos=0.43516713860184464, p_neg=0.564832861398154) ==> Tudo coloca política no meio, aff 🤨
# Gloeia a DEUS
# https://www.otempo.com.br/interessa/saude-e-ciencia/covid-19-chineses-concluem-que-hidroxicloroquina-nao-e-melhor-que-cuidado-usual-1.2316343 Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual OTEMPO.COM.BR Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual Covid-19: chineses concluem que hidroxicloroquina não é melhor que cuidado usual
# esse estudo foi só com a hidroxicloroquina, sem o antibiótico, na verdade muito paciente deve piorar por conta de infecção secundária bacteriana, além de que a azitromicina tem efeitos anti-inflamatórios que podem ajudar na resposta inflamatória pulmonar... De qualquer forma, saberemos logo do potencial ou não já que o mundo inteiro está usando agora, a partir de ontem basicamente muitos estudos começaram...
# o risco dessas noticias com a cloroquina como cura é exatamente esse de fazer as pessoas usarem sem entender como funciona ou sem base e critério, e causar casos como esse: https://oglobo.globo.com/sociedade/coronavirus-homem-morre-mulher-internada-nos-eua-apos-tomarem-cloroquina-24325000 Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina OGLOBO.GLOBO.COM Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina
# tem que tomar muito cuidado com isso..
# Automedicação no geral é algo perigoso, na verdade
# Já foi liberada nós hospitais ...vocês só bosta pessimistas querem ver as coisas dado errado nem consegui ficar feliz notícias boa
# https://noticias.uol.com.br/saude/ultimas-noticias/redacao/2020/03/25/cloroquina-cuidados-basicos-coronavirus.htm Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo NOTICIAS.UOL.COM.BR Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo Cloroquina não supera cuidados básicos contra a covid-19, afirma estudo
# https://gizmodo.uol.com.br/estudo-nao-encontra-evidencias-hidroxicloroquina-coronavirus/ Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil GIZMODO.UOL.COM.BR Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil Estudo limitado não encontra evidências de que hidroxicloroquina funciona contra coronavírus - Gizmodo Brasil
# https://oglobo.globo.com/sociedade/coronavirus-homem-morre-mulher-internada-nos-eua-apos-tomarem-cloroquina-24325000 Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina OGLOBO.GLOBO.COM Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina Coronavírus: Homem morre e mulher é internada nos EUA após tomarem cloroquina
# cloroquina de tanque de Aquário, por favor, neste momento pode não apoiar mas seja isento... Eu estou esperançosa mas isenta
# vc acha q eles cometeram essa imprudencia imbecil porque?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Porque a mídia espalhou a cloroquina como cura mágica... tem que ter muito cuidado com essas notícias, por isso, espalhar o nome do remédio nesse estagio da pesquisa ainda, é muito perigoso...
# Não sou contra a Cloroquina, só acho que temos que ter responsabilidade...
# concordo plenamente com você!
# Sentiment(classification='pos', p_pos=0.8392178931818546, p_neg=0.1607821068181446) ==> As pessoas precisam ser mais responsáveis em divulgar as coisas mas não temos controle, agora a mídia tem que informar de maneira assertiva... Os presidentes sem noção também tem... Eu sou farmacêutica, no meu ciclo eu aconselho a todos a aguardar, ainda não há dados... Mas quero ter esperança... Ao menos por enquanto, depois quero dados científicos, o quanto antes... Dez dias no máximo...
# tem ver na globo ..essa página.. pessimistas querem ver só lado errado tudo dando errado eu em
# fishfull think não ajuda nessas horas... sei que não podemo entrar em pânico, mas é importante entender a dimensão do caso, e ter responsabilidade diante de curas não testadas...
# Em alguns casos a cloroquina pode sim ser a cura, mas a dose é tão alta que tem que ser feita somente no hospital com médicos por perto porque se não souber administrar os efeitos colaterais são: arritmia cardíaca, infarto entre outras coisas relacionadas, então tomar muito cuidado com o que saem postando os desavisados podem sair usando de qualquer maneira e não pode
# Não é bem assim, vejam o que esse prof. explica sobre o assunto: https://youtu.be/raYslxs_VrY Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(classification='pos', p_pos=0.5085616438356164, p_neg=0.49143835616438347) ==> YOUTUBE.COM Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(classification='pos', p_pos=0.5085616438356164, p_neg=0.49143835616438347) ==> Live Coronavírus 25/03: Como o Brasil pode vencer a pandemia se estamos errando como EUA e Itália?
# Sentiment(classification='pos', p_pos=0.525, p_neg=0.4750000000000001) ==> Entrevista agora com a paciente na Record.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Vdd
# Está funcionando no mundo todo, um alívio para todos
# Isso, divulga!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> É somente com prescrição médica!!
# Sentiment(classification='neg', p_pos=0.38235294117647056, p_neg=0.6176470588235293) ==> Pode causar males também, se tomar por conta própria sabia?
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> 1
# Q bom graças a Deus
# Graças a Deus 💖 🙌
# ALELUIA
#
# #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao #bolsonarotemrazao
# o Bolsonaro inventou esse remédio ?
# Sentiment(classification='pos', p_pos=0.8928571428571435, p_neg=0.10714285714285716) ==> kkkkk gado e f... msm acredita ate que o bozo criou o remedio e tambem a cura kkkkkk
# TEU CÚ
# , Claro que não.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Esta sendo testado em todo o mundo.
# Sentiment(classification='pos', p_pos=0.7000000000000001, p_neg=0.3000000000000001) ==> (TESTE DE UM MEDICAMENTO A MUITO TEMPO NO MERCADO).
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> É bom que funcione .
# Sentiment(classification='pos', p_pos=0.833333333333333, p_neg=0.16666666666666646) ==> respeito bozo
# Bolsominion burro!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> TEU CÚ TAMBÉM
# Merece respeito quem sabe respeitar.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Não respeitou?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Então vai tomar no CÚ
# não Vadia, mas enquanto todos são contra o uso do remédio ele mandou produzir e pesquisar sobre a eficácia
# Não funciona.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Li sobre o estudo feito na Itália.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> E apenas um placebo para acalmar a população.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> … Ver mais
# Aonde vc viu isso?
# Sentiment(classification='pos', p_pos=0.745778971603991, p_neg=0.25422102839600924) ==> querida leia, desliga a Globo e vai ler está muito desinformada
# O estudo nem foi feito na Itália, foi na França...
# Primeiro que a dose de cloroquina é muito alta só deve ser feita no hospital pois se não o fizer corretamente se não morrer com o vírus morre de infarto e outros malefícios do próprio remedio
# Tambem deixou gente morta, entao, deixem para profissionais fazerem os testes, nao saiam por ai esgotando as farmacias, alem de estarem correndo riscos, esta tirando de quem realmente precisa
# já foi racionado justamente porque brasileiro não tem bom senso.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Agora só se compra com receita médica!
# Sentiment(classification='pos', p_pos=0.9390637610976592, p_neg=0.06093623890234063) ==> e lamentável
# Aqui em Santa Catarina a primeira morte contabilizada por corona vírus, o senhor de idade já estava doente a mais de um mês, um familiar mandou áudio avisando.
# Sentiment(classification='neg', p_pos=0.2901785714285711, p_neg=0.7098214285714285) ==> Ele ia e vinha do hospital, desenganado pelos médicos.
# Sentiment(classification='neg', p_pos=0.12499999999999985, p_neg=0.8749999999999998) ==> Numa dessas idas deve ter pego o vírus.
# Sentiment(classification='pos', p_pos=0.833333333333334, p_neg=0.16666666666666688) ==> Mas não fizeram nenhum exame pra saber.
# Sentiment(classification='pos', p_pos=0.75, p_neg=0.2499999999999997) ==> Simplesmente foi considerada a primeira morte do Estado.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> É um absurdo, estão espalhando pânico!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> fontes Mauricio?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Fontes?
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Pq não acredito
# - nunca tem fonte!!
# Sentiment(classification='pos', p_pos=0.5085616438356164, p_neg=0.49143835616438347) ==> Menos que alguem tenha sido curado que e bom, teve gente morrendo, entao o uso de remedios nao controlados, deixem so ao o uso de medicos eles sabem o que fazem
# https://youtu.be/zF2pXXJIAGM Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias YOUTUBE.COM Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias Live Coronavírus de 20/03 - O que o Brasil precisa fazer nos próximos dias
# Comparativo BRASIL X ITÁLIA ITALIA 14X + MORTES… Ver mais 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> YOUTUBE.COM 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> 📍 ¢σяσηανιяυѕ: A VERDADE REVELADA - VOCÊ É BURRO!!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> !🐴🐴🐴 ATILA IAMARINO, refute!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Pra quem não acredita, basta assistir o programa do Datena hoje.
# Sentiment(classification='neg', p_pos=0.375, p_neg=0.6249999999999998) ==> Datena não é confiável
# Glória a Deus
# Não demora muito e a #GloboLixo começa a condenar esse remédio....
# Vc é um bolsominion burrão!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> , calma, o carrinho com o pão com mortadela já passa pela tua rua.... 🤣 🤣 🤣 🤣 🤣
# Vc é um completo idiota!!
# Sentiment(classification='pos', p_pos=0.833333333333333, p_neg=0.16666666666666646) ==> Odeio tanto os adoradores do Luladrão como os imbecis como vc, que não ouvem as autoridades médicas, os infectologistas e sim o Bozo tresloucado!!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Parem de politizar isso, nessa hora tem esquerda e nem direita bando de imbecil
# Bando de jumentos A imagem pode conter: texto que diz "Lula Livre!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Bolsonaro mito!"
# Sentiment(classification='neg', p_pos=0.284090909090909, p_neg=0.7159090909090902) ==> Segundo eu li em uma postagem (Não me lembro onde) cloroquina +azitromicina=cura
# Em Milão eles ainda não sabiam da virulência tão trágica do novo coronavírus.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Nós agora sabemos!
# Sentiment(classification='neg', p_pos=0.16666666666666607, p_neg=0.833333333333334) ==> E é bem forte esta Palavra de Deus: "... Eu lhes propus a vida ou a morte, a bênção ou a maldição.
# Sentiment(classification='pos', p_pos=0.8141282565130264, p_neg=0.18587174348697436) ==> Escolha, portanto, a vida, para que você e seus descende… Ver mais
# A imagem pode conter: atividades ao ar livre, texto que diz "CARREATA NA ITÁLIA DEPOIS DA LIBERAÇAO DO COMERCIO COM @DOUGLASREZENDEPSOL 니 ADENN PHARMACIE CAMINHÕES DO EXÉRCITO COM CAIXOES LAUTADOS"
# Conheço uma pessoa com asma Que teve , foi 3 vezes no hospital , por fim detectaram pneumonia Mas ela está curada … Ver mais
# ????
# Sentiment(classification='neg', p_pos=0.10000000000000028, p_neg=0.9000000000000002) ==> não consegui saber o remédio q foi usado
# DIÓXIDO DE CLORO - CLO2 - MMS "O dióxido de cloro é registrado na Agência de Proteção Ambiental dos Estados Unidos (EPA) como desinfetante, desinfetante e esterilizador, definido como a capacidade" de destruir ou eliminar todas as formas de vida microbiana, incluindo fungos, vírus e todas as formas de bactérias e seus esporos ".
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Abaixo estão alguns dos organismos mais comumente vistos que o Dióxido de Cloro foi eliminado.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Até o momento, nenhum organismo testado contra o Dióxido de Cloro provou ser resistente."
# Sentiment(classification='pos', p_pos=0.7363636363636369, p_neg=0.2636363636363634) ==> E o coronavírus está na lista E vírus corona da Síndrome Respiratória Aguda Grave (SARS)!
# Sentiment(classification='neg', p_pos=0.31946072684642385, p_neg=0.6805392731535752) ==> Créditos Scott M https://drive.google.com/file/d/1Jqqr1qMWBZz8OGDJsbV84BJzAaahaDIX/view?usp=drivesdk Chlorine dioxide registered as a biocide by EPA.pdf DRIVE.GOOGLE.COM Chlorine dioxide registered as a biocide by EPA.pdf Chlorine dioxide registered as a biocide by EPA.pdf
# Porque a gente gosta de números!
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Leiam com atenção.
# Sentiment(classification='neg', p_pos=0.284090909090909, p_neg=0.7159090909090902) ==> "A leitura desse texto é extremamente importante para que se entenda de uma vez que isso não é “gripizinha” e ações de supressão precoce farão toda a diferença!!
# Sentiment(classification='pos', p_pos=0.85046318479476, p_neg=0.14953681520523893) ==> Fonte: ProEpi - Associação Brasileira de Profissionais de Epidemiologia de Campo “Saiu a modelagem estatística do Imperial College London para os cenários do COVID-19 no Brasil.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> Antes, uma introdução.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> No começo da pandemia o governo do Reino Unido havia decidido apostar em uma estratégia de “imunidade de massa”, que consistia em não tomar medidas restritivas; em vez de parar o país, deixariam que o vírus infectasse a população de modo que rapidamente as pessoas pudessem ficar imunizadas.
# Sentiment(classification='pos', p_pos=0.8713100536719462, p_neg=0.12868994632805372) ==> Porém, o governo do Reino Unido desistiu dessa ideia quando uma equipe de especialistas epidemiológicos do Imperial College of London apresentou uma previsão de como se desenrolaria a disseminação do COVID-19 em diferentes cenários de contenção para o Reino Unido e para os Estados Unidos.
# Sentiment(classification='pos', p_pos=0.6079258010118043, p_neg=0.39207419898819534) ==> Para elaborar essa previsão, utilizaram dados de contágio, estatísticas de hospitalização e óbitos vistos em outros países, estudaram como o vírus se dissemina em diferentes ambientes etc.. Como um breve resumo: se circular livremente, o vírus tem a capacidade de infectar cerca de 80% da população geral em um período muito curto.
# Sentiment(classification='pos', p_pos=0.9166666666666673, p_neg=0.08333333333333334) ==> Das pessoas infectadas, cerca de 20% precisam de hospitalização, 5% dos casos são críticos e precisam de UTI e suporte respiratório, e cerca de metade dos casos críticos vêm a óbito.
# Sentiment(classification='pos', p_pos=0.5508474576271188, p_neg=0.4491525423728814) ==> No entanto, o súbito aumento de casos ultrapassa a capacidade do sistema de saúde, gerando colapso, e disso resulta um número muito maior de mortes — de covid-19, assim como de outras causas — simplesmente porque não há hospital para tratar todas as pessoas que precisam.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Segundo a previsão, se não houver restrições nos contatos, no mundo inteiro seriam 7 bilhões de pessoas infectadas com covid-19 e 40 milhões de mortes neste ano.
# Sentiment(classification='pos', p_pos=0.9166666666666662, p_neg=0.08333333333333334) ==> Os números previstos por esses estudos fizeram com que governos desistissem das posturas mais relaxadas e tomassem as medidas mais restritivas para evitar o colapso do sistema de saúde e um número muito maior de mortes.
# Sentiment(classification='pos', p_pos=0.85046318479476, p_neg=0.14953681520523893) ==> # Ontem, no dia 26/03/2020, o Imperial College of London soltou números previstos para os desfechos da pandemia em todos os países, nos cenários sem intervenção, com mitigação, e com supressão.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Mitigação envolve proteger os idosos (reduzir 60% dos contatos) e restringir apenas 40% dos contatos do restante da população.
# Sentiment(classification='neg', p_pos=0.43103448275862066, p_neg=0.5689655172413793) ==> Supressão envolve testar e isolar os casos positivos, e estabelecer distanciamento social para toda a população.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> Supressão precoce – implementada em uma fase em que há 0,2 mortes por 100.000 habitantes por semana e mantida Supressão tardia – implementada quando há 1,6 mortes por 100.000 habitantes por semana e mantida.
# Sentiment(classification='neg', p_pos=0.3604922667232724, p_neg=0.6395077332767274) ==> # No Brasil os cenários previstos são os seguintes: Cenário 1- Sem medidas de mitigação: - População total: 212.559.409 - População infectada: 187.799.806 - Mortes: 1.152.283 - Indivíduos necessitando hospitalização: 6.206.514 - Indivíduos necessitando UTI: 1.527.536 # Cenário 2 - Com distanciamento social de toda a população: - População infectada: 122.025.818 - Mortes: 627.047 - Indivíduos necessitando hospitalização: 3.496.359 - Indivíduos necessitando UTI: 831.381 # Cenário 3 - Com distanciamento social E REFORÇO do distanciamento dos idosos: - População infectada: 120.836.850 - Mortes: 529.779 - Indivíduos necessitando hospitalização: 3.222.096 - Indivíduos necessitando UTI: 702.497 # Cenário 4 – Com supressão tardia - População infectada: 49.599.016 - Mortes: 206.087 - Indivíduos necessitando hospitalização: 1.182.457 - Indivíduos necessitando UTI: 460.361 - Demanda por hospitalização no pico da pandemia: 460.361 - Demanda por leitos de UTI no pico da pandemia: 97.044 # Cenário 5 – Com supressão precoce - População infectada: 11.457.197 - Mortes: 44.212 - Indivíduos necessitando hospitalização: 250.182 - Indivíduos necessitando UTI: 57.423 - Demanda por hospitalização no pico da pandemia: 72.398 - Demanda por leitos de UTI no pico da pandemia: 15.432 # Faço algumas observações: Os próprios autores do estudo comentam que modelaram essas curvas com base nos padrões de dispersão dos países ricos e que nos países pobres os resultados da pandemia podem ser piores do que o previsto.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> Esses números previstos não levam em conta a existência de favelas, comunidades sem abastecimento de água e/ou saneamento, entre outros complicadores que temos no Brasil.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> # É preciso comentar que os números reais da pandemia no Brasil, seus casos e óbitos, estarão amplamente subnotificados devido à falta de testes e demora nos resultados.
# Sentiment(classification='pos', p_pos=0.7083333333333333, p_neg=0.29166666666666663) ==> As estatísticas oficiais publicadas pelo Ministério da Saúde mostrarão apenas a ponta do iceberg.
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5) ==> # Mesmo nos melhores cenários, lentificando a transmissão e aumentando os recursos do sistema de saúde, deve faltar UTI e respirador para parte dos doentes.
# Sentiment(classification='pos', p_pos=0.5434782608695654, p_neg=0.4565217391304346) ==> # Em resumo, a diferença entre ficarmos todos em casa (supressão) ou adotar uma estratégia mais branda de mitigação e proteção apenas dos grupos de risco pode ser da ordem de MEIO MILHÃO de vidas.
# Sentiment(classification='pos', p_pos=0.9324695153653434, p_neg=0.06753048463465937) ==> # Os diversos relatórios estão disponíveis no site do Imperial College of London: https://www.imperial.ac.uk/mrc-global-infectious-disease-analysis/news--wuhan-coronavirus/?fbclid=IwAR0GeexFNu6ezOVclPBVW5x3Z3yOn5N1X6siDO5P7ezUOm_UwOUu31RBoAY Link para o trabalho “The Global Impact of COVID-19 and Strategies for Mitigation and Suppression”: https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/Imperial-College-COVID19-Global-Impact-26-03-2020.pdf As tabelas com os números oferecidos constam no apêndice: https://www.imperial.ac.uk/media/imperial-college/medicine/sph/ide/gida-fellowships/Imperial-College-COVID19-Global-unmitigated-mitigated-suppression-scenarios.xlsx “ IMPERIAL.AC.UK COVID-19 reports COVID-19 reports
# Esse remédio curou a malária (leiam no Google,sobre essa...) Cientistas vão misturar , testar , várias fórmulas...

# %% [markdown]
# ### Sentimento e posicionamento
# Como eu meio que já previa isso, criei [uma versão anotada](https://docs.google.com/spreadsheets/d/1e6F5_esHtzdHgX14eGED8o1Rh_mUt_59Vohz9hYbQaE/edit#gid=1791126449) dos datasets, que classifica cada manifestação dos usuários em _positivo_ (a favor do uso da cloroquina no tratamento da Covid-19), _negativo_ (contra o uso da cloroquina) ou _neutro_ numa coluna chamada **Posicionamento** (_stance_). Essa anotação foi feita de modo manual, lendo comentário por comentário e atribuindo-lhe uma classificação — [neste artigo](https://arxiv.org/pdf/1605.01655.pdf), Mohammad et al. (2016) expõe uma metodologia completa para isso, que envolve um time numeroso de pesquisadores-anotadores que validam entre si as suas marcações. Alguns desses comentários expressavam concordância com o uso da cloroquina apenas em alguns casos (mais graves, ou no início da infecção pela doença); esses comentários foram classificados como _positivos_ por estarem de acordo com o uso do medicamento no tratamento dessa enfermidade, ainda que de maneira contida.
#
# Também fiz uma versão do primeiro dataset anotada manualmente com o **sentimento** (_positivo_, _negativo_ ou _neutro_) predominante de cada texto, que acabou não sendo usada. Um dos motivos é a dificuldade de se atribuir valores a sentimentos sem uma metodologia de rotulagem específica para isso nem uma equipe de pesquisadores para auxiliar e validar o processo; inferir e rotular posicionamento em um contexto como este é muito mais simples que inferir sentimento e atribuir a ele uma valência. Posicionamento é diferente de sentimento, ainda que possam estar relacionados. A análise de sentimento busca as relações positivas e negativas na linguagem dos usuários, enquanto que análises que buscam inferir posicionamentos buscam a opinião dos usuários sobre um dado tema.

# %% [markdown]
# ## Naive Bayes e TextBlob
# O Naive Bayes é uma fórmula de _cálculo probabilístico_, uma quantificação de um processo lógico. Seu objetivo é encontrar a probabilidade entre duas relações, corrigindo essa probabilidade quando alimentado com dados novos. Aqui, ele é treinado com dados rotulados e depois o modelo é testado para avaliar sua acurácia. Em teoria, quanto mais alimentado o modelo, melhor ele aprende.

# %%
# importando classificadores
from textblob.classifiers import NaiveBayesClassifier
import csv

# importando os dados diretamente em forma de tuplas
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento7-treino.csv', newline='') as f1:
  treino = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento7-teste.csv', newline='') as f2:
  teste = [tuple(row) for row in csv.reader(f2)]

cl = NaiveBayesClassifier(treino)
cl.update(teste)
cl.accuracy(teste)
# Out:
# 0.8347826086956521

# %% [markdown]
# Aparentemente, tudo está funcionando e o classificador retorna uma acurácia alta. Porém, ainda que o Naive-Bayes seja um bom classificador, apropriado para uma série de tarefas que incluem identificar emails que são spams ou detectar linguagem imprópria em fóruns de discussão, ele não é um bom estimador. Além disso, há dúvidas se a classificação dele realmente funciona direitinho, porque quando esse modelo é alimentado com novos dados, a capacidade de identificar padrões se reduz drasticamente, vide abaixo.

# %%
# importando os dados diretamente em forma de tuplas, exatamente como da outra vez
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento1-treino.csv', newline='') as f1: treino1 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento1-teste.csv', newline='') as f1: teste1 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento2-treino.csv', newline='') as f1: treino2 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento2-teste.csv', newline='') as f1: teste2 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento3-treino.csv', newline='') as f1: treino3 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento3-teste.csv', newline='') as f1: teste3 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento4-treino.csv', newline='') as f1: treino4 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento4-teste.csv', newline='') as f1: teste4 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento5-treino.csv', newline='') as f1: treino5 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento5-teste.csv', newline='') as f1: teste5 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento6-treino.csv', newline='') as f1: treino6 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento6-teste.csv', newline='') as f1: teste6 = [tuple(row) for row in csv.reader(f1)]

with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento7-treino.csv', newline='') as f1: treino7 = [tuple(row) for row in csv.reader(f1)]
with open('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento7-teste.csv', newline='') as f1: teste7 = [tuple(row) for row in csv.reader(f1)]

# %%
# Criando e treinando o classificador
myClassifier = NaiveBayesClassifier(treino1)
myClassifier.update(treino2)
myClassifier.update(treino3)
myClassifier.update(treino4)
myClassifier.update(treino5)
myClassifier.update(treino6)
myClassifier.update(treino7)
# Out:
# True

# %% [markdown]
# Vixe, pior que tacar uma moeda pra cima e chutar o resultado! 😬

# %%
# acurácia pior que a de um ser humano!
print(myClassifier.accuracy(teste1))
print(myClassifier.accuracy(teste2))
print(myClassifier.accuracy(teste3))
print(myClassifier.accuracy(teste4))
print(myClassifier.accuracy(teste5))
print(myClassifier.accuracy(teste6))
print(myClassifier.accuracy(teste7))
# Out:
# 0.47115384615384615
# 0.5244755244755245
# 0.33695652173913043
# 0.47058823529411764
# 0.3443708609271523
# 0.43089430894308944
# 0.3652173913043478

# %%
# alguns dos aspectos informativos parecem fazer sentido, mas não todos
myClassifier.show_informative_features(20)
# Out:
# Most Informative Features
#       contains(eficácia) = True           Negati : Neutro =     12.3 : 1.0
#              contains(🙏) = True           Positi : Neutro =     11.5 : 1.0
#       contains(hospital) = True           Positi : Negati =      9.7 : 1.0
#        contains(ciência) = True           Negati : Positi =      9.4 : 1.0
#         contains(errado) = True           Negati : Neutro =      9.3 : 1.0
#             contains(dá) = True           Negati : Neutro =      9.3 : 1.0
#            contains(EUA) = True           Negati : Positi =      8.7 : 1.0
#         contains(idiota) = True           Negati : Positi =      7.9 : 1.0
#          contains(Trump) = True           Negati : Neutro =      7.8 : 1.0
#        contains(malária) = True           Positi : Neutro =      7.6 : 1.0
#       contains(sintomas) = True           Neutro : Negati =      7.5 : 1.0
#      contains(protocolo) = True           Positi : Negati =      7.4 : 1.0
#     contains(científica) = True           Negati : Positi =      7.2 : 1.0
#      contains(população) = True           Negati : Positi =      7.2 : 1.0
#          contains(vezes) = True           Negati : Positi =      7.2 : 1.0
#   contains(dexametasona) = True           Neutro : Positi =      7.1 : 1.0
#          contains(forma) = True           Negati : Neutro =      7.1 : 1.0
#            contains(fez) = True           Negati : Neutro =      7.1 : 1.0
#          contains(mundo) = True           Negati : Neutro =      7.1 : 1.0
#             contains(lá) = True           Negati : Neutro =      6.9 : 1.0

# %% [markdown]
# Como aqui ele não está fazendo nenhuma análise de estrutura das informações, tem como entrada informações muito caóticas e pouco estruturadas, e não existe o auxílio dos corpos léxicos anotados, fica difícil confiar na precisão desse modelo. Abaixo, a probabilidade de nosso modelo treinado classificar a frase de exemplo como positiva, negativa ou neutra.

# %%
# enfim, ainda tenho minhas dúvidas
myClassifier.prob_classify('Você sabe que deveria consultar um médico antes de tomar a cloroquina, né?').prob('Positivo')
# Out:
# 0.8610267590853651

# %% [markdown]
# ## Naive Bayes e SciKit Learn
# O modelo abaixo usa a mesma lógica de aprendizagem de máquina que as tentativas nos blocos anteriores, e é baseado [neste experimento](https://www.kaggle.com/leandrodoze/sentiment-analysis-in-portuguese). Ele faz uso de algumas das bibliotecas que usamos aqui, mas seus resultados também não são muito melhores. Mais adiante discutiremos o porquê e as possíveis soluções para experimentos futuros. O SciKit Learn, ferramenta de tratamento estatístico e aprendizagem de máquina que vamos usar nessa implementação, tem [módulos](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) bastante interessantes para lidar com texto que precisam ser melhor explorados no futuro.

# %% [markdown]
# ### Construindo o modelo
# Aqui, vamos separar o conteúdo de seu rótulo classificatório para que possamos enfim criar a bag-of-words — que cria vetores para cada palavra conforme sua frequência de uso — para depois aplicar o Naive Bayes.

# %%
# o caminhão de bibliotecas e módulos usados aqui
import nltk, re
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import cross_val_predict

# conteúdo e posicionamentos em variáveis separadas
treino = pd.read_csv('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento1-treino.csv', encoding='utf-8')

content = treino['content'].values
stance = treino['stance'].values

# tentando uma implementação com as stopwords identificadas anteriormente
# a linha comentada abaixo é uma implementação do vetorizador considerando unigramas e bigramas: não deu muito bom
# vectorizador = CountVectorizer(ngram_range = (1, 2))
vectorizador = CountVectorizer(analyzer = "word", stop_words=('a1-tomando-hidroxicloroquina/a-53490069', 'maca=pt-br-facebook-sharing', '…ver', '21.05.2020', 'el', 'la', '1a', 'id=111037913835511', 'story_fbid=142404497365519', 'angu…ver', 'cartacapital.com.br', '83', '0:08', '‎‎9', 'rfi', '2:15', '‎11:13', 'مه', '79', 'dp', '6:20', '0:29', '05/06/2020', 'A1rmaco-contra-la-malaria-para-combatir-el-coronavirus/a-53525047', '28x', '55', 'pessoa…ver', 'salvado…ver', 'rebanho…ver', 'revistagalileu.globo.com', '22:45', '000', '2comentários', '2:33', '5x', '×', 'messeng…ver', '23:19', 'usoalideatdatr.coacmacegamos', 'rob…ver', 'derivados.…ver', '35.000', 'nã…ver', 'n', '1,5', 'cr', '90.000', '19', 'td', 'veja.abril.com.br', '90', 'not', '7:12', '20_05_2020', 'consultaremedios.com.br', 'id=636938300054720', 'story_fbid=1019342698480943', 'b', '25a3o-de-casos-de-covid-19-1.424102', '25ADcias/geral/eua-passa-de-90-000-mortes-e-1-5-milh%25C3%25A3o-de-casos-de-covid-19-1.424102%3famp=1', 'correiodopovo.com.br', 'ciencia.estadao.com.br', 'utm_medium=link', '3afacebook', '30', '6', 'utm_source=estadao', 'it', 'id=100003639170871', 'story_fbid=1870871703044117', 'http://www.gazetadopovo.com.br/republica/breves/coronavirus-sociedade-brasileira-imunologia-cloroquina', 'gazetadopovo.com.br', 'dailymail.co.uk', '1…ver', '14', '508', 'w', '400', 'c3', 'v=uijcuwvardy', 'entã…ver', '16', '96000', 'https://www.medrxiv.org/content/10.1101/2020.04.07.20056424v2', 'feature=youtu.be', 'v=vmdyiiidml8', '68', '08', 'media1.tenor.co', 'necessit…ver', 'giphy', 'es', 'unicamp.br', 't', 'id=100000982583520', 'story_fbid=3937748652934515', 'www1.folha.uol.com.br', 'correiobraziliense.com.br', 'maca=pt-br-facebook-sharing', '12:53', '94', '99', 'l…ver', 'lamarque/reuters', '1.000', 'd3', 'g1.globo.com', 'a1-tomando-hidroxicloroquina/a-53490069', '70', '01:29', '01:30', '8', 'n', '11', 'fbclid=IwAR00ntGTutiH3TOgQA18xBFpHmMnMKQ4CeGORpPYRwnYqe4-z-7sBACkS4w', 'v=imyfz7ri8vc', 'v=zer6omw0vnu', '2002', 'v=wa2om70v66o', 'x', 'ufpr.br', '11.°', '14', 'luciliadiniz.com', '11:56', '348', '428', 'ea', '15', 'médicosrevistacrescer.globo.com', 'pel…', 'saude.estadao.com.br', 'qq', 'di…ver', 'di…ver', 'vi…ver', '67', 'infart…ver', 'acredita…ver	', 'q…ver', 'a…ver', 'chat.whatsapp.com', '500mg', '450', '90', '200mg', 'e…ver', '30', 'n9', 'ñ', 'c', 'tb', '30', 'i', '07/04', '24', 'and', 'so', '’', '‘', '500', 'at', 'id=100031212156711', 'story_fbid=241150380268699', '03', '13/03/2020', '2/2', '25876', '01441', '2000', '5.000', 'the', '23:11', 'www.google.com', '21:35', 'ii', 'mg/kg', 'qd', '’', 'so', 'c', 'est', '»', 'noticias.r7.com', 'he', '19', 'www1.folha.uol.com.br', '23:22', '24', 'bloomberg.com', 'co…', 'google.com', 'to', 'is', 'it', 'oh', '川', '5:27', 'neh', 'brasil.elpais.com	', 'afff', '3foutputtype=amp', '36', '90', '400', 'c', '🥱', 'tô', 'mi', 'rs', 'correiobraziliense.com.br', 'r', 'agr', 'ô', '819', 'pre', '19', 'uai', '14', 'so', 'twitch.tv', '13', '2003', 'afz', 'hein', '35', 'media1.tenor.co', 'á', 'giphy', 'g1.globo.com', 'b382022', '2,5', '18.000.00', 'epoca.globo.com', 'veja.abril.com.br', 'id=100002238746462', 'story_fbid=3034985226586072', 'ê', 'o', 'aff', '39', '16', 'brakkkkkkkkkkkk', 'k', 'afffff', '8', '5,3', '15', '7.599', '3.120', 'gb', '64', '11', '16,5', '400', 'n', '18', 'ueh', '900', 'amp=1', '2o', 'bvsms.saude.gov.br/bvs/sus/comissoes.php', 'bvsms.saude.gov.br', 'http', 'usg=aovvaw2rb7swa3zpjklxt9uikurm', 'ved=2ahukewjslo6_7nlqahxvqd8khyh1dz0qfjahegqibrac', 'url=https', 'url=https', 'rct=j', 'source=web', 'sa=t', 'g', '25', 'नपूण‎', 'د', 'https://www.correiobraziliense.com.br/app/noticia/politica/2020/07/16/interna_politica,872688/amp.htm', 'muita', 'q', '2', '1', 'uol.com.br', 'om', 'apenas', 'antes', 'olha', 'assim', 'todo', 'twitch', 'pro', 'qualquer', 'gif', 'tenor', 'imagem', 'coisa', 'quanto', 'outros', 'algum', 'outra', 'ja', 'ainda', 'lá', 'vou', 'tão', 'falou', 'devem', 'podem', 'sinoussi', 'barré', 'françoise', 'tá', 'têm', 'pode', 'após', 'https', 'pois', 'uol', 'istoé', 'vai', 'toda', 'tudo', 'sim', 'bolsonarotemrazao', 'outro', 'onde', 'vez', 'pós', 'ter', 'vem', 'vão', 'google amp', 'né', 'tiraram', 'noticias', 'r7', 'eh', 'disse', 'algo', 'então', 'desse', 'dizer', 'quê', 'sendo', 'tbm', 'pra', 'aí', 'dessa', 'deve', 'sob', 'br', 'dar', 'dá', 'etc', 'ai', 'imagem pode', 'conter', 'cada', 'deu', 'vc', 'nao', 'aponta', 'pq', 'sobre', 'quer', 'ta', 'deixa', 'iwar0geexfnu6ezovclpbvw5x3z3yon5n1x6sido5p7ezuom_uwouu31rboay', 'fbclid=iwar2srohpl8geeqr8a9zyz17hpgmms4hh1q87ffficm_ek0v9srs5lgqsn68', '“', '”', 'p', '-', '…', '3', 'm', 'oglobo.globo.com', '10', '75', 'x', 'youtube.com', '20/03', '25/03', '26/03/2020', 's', '40', '60', '—', '460.361', '100', '100.000', 'istoe.com.br', '5', 'oq', '1.527.536', '122.025.818', '6.206.514', '1.152.283', '187.799.806', '627.047', '120.836.850', '831.381', '3.496.359', 'imperial.ac.uk', '1,6', '212.559.409', 'f', '529.779', '15.432', '72.398', '57.423', 'otempo.com.br', '206.087', '49.599.016', '4', '702.497', '250.182', '44.212', '11.457.197', '97.044', 'e/ou', 'noticias.uol.com.br', 'gizmodo.uol.com.br', '1.182.457', '0,2', '7', '니', 'usp=drivesdk', 'drive.google.com', '80', '20', 'clo2', '14x', '0:02', '0:00', 'ப', 'h', '4e', 'cmpid=copiaecola', '18:46', 'd', '27/03', '12h', 'av', 'ah', '²', '12', 'covidvisualizer.com', '17:30', '1,2kb/s', '19:34', 'è', '口', '444', 'u', '24/03/20', '08h38', '520', '09:50'))
freqTrain = vectorizador.fit_transform(content)

# treinando o modelo
modelo = MultinomialNB()
modelo.fit(freqTrain, stance)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['00', '01', '016', '02', '025', '04', '044', '047', '05', '06', '07', '087', '09', '100000982583520', '100002238746462', '100003639170871', '100031212156711', '1019342698480943', '1101', '111037913835511', '120', '122', '142404497365519', '152', '17', '182', '187', '1870871703044117', '197', '20056424v2', '2020', '206', '21', '212', '22', '23', '241150380268699', '250', '25a3o', '25adcias', '25c3', '26', '27', '283', '29', '2ahukewjslo6_7nlqahxvqd8khyh1dz0qfjahegqibrac', '2kb', '3034985226586072', '33', '34', '359', '361', '381', '3937748652934515', '398', '3famp', '3foutputtype', '409', '423', '424102', '432', '44', '45', '457', '46', '460', '49', '496', '497', '50', '514', '527', '529', '53', '53490069', '53525047', '536', '559', '56', '57', '599', '627', '636938300054720', '702', '72', '779', '799', '7sbacks4w', '806', '818', '831', '836', '850', '872688', '97', 'a1', 'a1rmaco', 'abril', 'ac', 'acredita', 'amp', 'angu', 'aovvaw2rb7swa3zpjklxt9uikurm', 'app', 'be', 'bloomberg', 'brasil', 'brasileira', 'breves', 'bvs', 'bvsms', 'cartacapital', 'casos', 'chat', 'ciencia', 'cloroquina', 'cmpid', 'co', 'coacmacegamos', 'com', 'combatir', 'comissoes', 'consultaremedios', 'content', 'contra', 'copiaecola', 'coronavirus', 'correiobraziliense', 'correiodopovo', 'covid', 'covidvisualizer', 'dailymail', 'de', 'derivados', 'di', 'drive', 'drivesdk', 'elpais', 'entã', 'epoca', 'estadao', 'eua', 'facebook', 'fbclid', 'feature', 'folha', 'g1', 'gazetadopovo', 'geral', 'gizmodo', 'globo', 'google', 'gov', 'hidroxicloroquina', 'htm', 'id', 'imperial', 'imunologia', 'imyfz7ri8vc', 'infart', 'interna_politica', 'istoe', 'iwar00ntgtutih3togqa18xbfphmmnmkq4cegorppyrwnyqe4', 'iwar2srohpl8geeqr8a9zyz17hpgmms4hh1q87ffficm_ek0v9srs5lgqsn68', 'kg', 'lamarque', 'link', 'luciliadiniz', 'maca', 'malaria', 'media1', 'medrxiv', 'messeng', 'mg', 'milh', 'mortes', 'médicosrevistacrescer', 'necessit', 'noticia', 'nã', 'oglobo', 'org', 'otempo', 'ou', 'para', 'passa', 'pel', 'pessoa', 'php', 'politica', 'pt', 'rct', 'rebanho', 'republica', 'reuters', 'revistagalileu', 'rob', 'sa', 'salvado', 'saude', 'sharing', 'sociedade', 'source', 'story_fbid', 'sus', 'tomando', 'tv', 'ufpr', 'uijcuwvardy', 'uk', 'unicamp', 'url', 'usg', 'usoalideatdatr', 'usp', 'utm_medium', 'utm_source', 'ved', 'veja', 'ver', 'vi', 'vmdyiiidml8', 'wa2om70v66o', 'web', 'whatsapp', 'www', 'www1', 'youtu', 'youtube', 'zer6omw0vnu', 'नप'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# testando o modelo
teste = pd.read_csv('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/posicionamento1-teste.csv',encoding='utf-8')

freqTeste = vectorizador.transform(teste)
modelo.predict(freqTeste)
# Out:
# array(['Positivo', 'Positivo'], dtype='<U8')

# %%
# validação do modelo dividindo a amostra em 10 partes (cv)
resultados = cross_val_predict(modelo, freqTrain, stance, cv = 10)

# %%
# acurácia desse modelo: 0.5391... usando n-gramas e 0.6173... sem eles.
metrics.accuracy_score(stance, resultados)
# Out:
# 0.6173913043478261

# %%
# validação estatítica do modelo
posic = ["Positivo", "Negativo", "Neutro"]
print(metrics.classification_report(stance, resultados, posic))
# Out:
#               precision    recall  f1-score   support
#
#     Positivo       0.67      0.80      0.73       135
#     Negativo       0.00      0.00      0.00        22
#       Neutro       0.53      0.47      0.50        73
#
#     accuracy                           0.62       230
#    macro avg       0.40      0.42      0.41       230
# weighted avg       0.56      0.62      0.58       230

# %%
# matriz-confusão
print(pd.crosstab(stance, resultados, rownames = ["Real"], colnames=["Predito"], margins=True))
# Out:
# Predito   Negativo  Neutro  Positivo  All
# Real
# Negativo         0       6        16   22
# Neutro           1      34        38   73
# Positivo         3      24       108  135
# All              4      64       162  230

# %% [markdown]
# Essa implementação é um pouco mais sofisticada que a do sandbox anterior, mas ainda assim não trouxe uns resultados muito melhores não. Ambos os algoritmos performam pior que um ser humano nessa tarefa específica, e quando melhoram, é muito pouco. Isso porque, além de não ter como fazer uso das bases e corpos léxicos disponívels, os dados aqui são muito pouco estruturados, pouco homogêneos, caóticos mesmo.

# %% [markdown]
# ## Bônus: nuvens de posicionamentos
# Como temos todo o dataset anotado com as posições dos usuários a respeito do uso ou não da cloroquina no tratamento da Covid-19 e temos o _know-how_ todo prontinho para a construção de Wordclouds, não faz sentido deixar isso pra lá sem uso só porque o nosso experimento aqui deu ruim. Como vimos nos experimentos anteriores, visualizações simples como as nuvens de palavras podem ser bem interessantes.

# %%
# importando uma versão do dataset com todos os comentários de todas as thread aglutinados
pos = pd.read_csv('/content/drive/My Drive/Acadêmico/~COMU 7007/~Artigo/dataframes/CSV/sentimento/tudo/posicionamento-tudo.csv',encoding='utf-8')

posNeg, posPos, posNeu = '', '', ''

for i in pos[pos.stance == 'Negativo'].content: posNeg = posNeg + i + ' '
for i in pos[pos.stance == 'Positivo'].content: posPos = posPos + i + ' '
for i in pos[pos.stance == 'Neutro'].content: posNeu = posNeu + i + ' '

# %%
# importando um caminhão de bibliotecas
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
from PIL import Image

nltk.download('stopwords')
nltk.download('punkt')

links = []

# essa função gera uma lista com todas as palavras de cada thread e armazena os links encontrados no array "links"
def tokeniz(data):
  blob = TextBlob(data)
  palavras = blob.words.lower()

  j = 0
  for i in palavras:
    j = j + 1
    if i == "https":
      links.append(palavras[j])
      palavras.pop(j)

  return palavras
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# separando as opiniões/posicionamentos
cloudNeg, cloudPos, cloudNeu = '', '', ''

for i in tokeniz(posNeg): cloudNeg = cloudNeg + i + ' '
for i in tokeniz(posPos): cloudPos = cloudPos + i + ' '
for i in tokeniz(posNeu): cloudNeu = cloudNeu + i + ' '

# conjunto das stopwords catadas à mão
stop = ['a1-tomando-hidroxicloroquina/a-53490069', 'maca=pt-br-facebook-sharing', '…ver', '21.05.2020', 'el', 'la', '1a', 'id=111037913835511', 'story_fbid=142404497365519', 'angu…ver', 'cartacapital.com.br', '83', '0:08', '‎‎9', 'rfi', '2:15', '‎11:13', 'مه', '79', 'dp', '6:20', '0:29', '05/06/2020', 'A1rmaco-contra-la-malaria-para-combatir-el-coronavirus/a-53525047', '28x', '55', 'pessoa…ver', 'salvado…ver', 'rebanho…ver', 'revistagalileu.globo.com', '22:45', '000', '2comentários', '2:33', '5x', '×', 'messeng…ver', '23:19', 'usoalideatdatr.coacmacegamos', 'rob…ver', 'derivados.…ver', '35.000', 'nã…ver', 'n', '1,5', 'cr', '90.000', '19', 'td', 'veja.abril.com.br', '90', 'not', '7:12', '20_05_2020', 'consultaremedios.com.br', 'id=636938300054720', 'story_fbid=1019342698480943', 'b', '25a3o-de-casos-de-covid-19-1.424102', '25ADcias/geral/eua-passa-de-90-000-mortes-e-1-5-milh%25C3%25A3o-de-casos-de-covid-19-1.424102%3famp=1', 'correiodopovo.com.br', 'ciencia.estadao.com.br', 'utm_medium=link', '3afacebook', '30', '6', 'utm_source=estadao', 'it', 'id=100003639170871', 'story_fbid=1870871703044117', 'http://www.gazetadopovo.com.br/republica/breves/coronavirus-sociedade-brasileira-imunologia-cloroquina', 'gazetadopovo.com.br', 'dailymail.co.uk', '1…ver', '14', '508', 'w', '400', 'c3', 'v=uijcuwvardy', 'entã…ver', '16', '96000', 'https://www.medrxiv.org/content/10.1101/2020.04.07.20056424v2', 'feature=youtu.be', 'v=vmdyiiidml8', '68', '08', 'media1.tenor.co', 'necessit…ver', 'giphy', 'es', 'unicamp.br', 't', 'id=100000982583520', 'story_fbid=3937748652934515', 'www1.folha.uol.com.br', 'correiobraziliense.com.br', 'maca=pt-br-facebook-sharing', '12:53', '94', '99', 'l…ver', 'lamarque/reuters', '1.000', 'd3', 'g1.globo.com', 'a1-tomando-hidroxicloroquina/a-53490069', '70', '01:29', '01:30', '8', 'n', '11', 'fbclid=IwAR00ntGTutiH3TOgQA18xBFpHmMnMKQ4CeGORpPYRwnYqe4-z-7sBACkS4w', 'v=imyfz7ri8vc', 'v=zer6omw0vnu', '2002', 'v=wa2om70v66o', 'x', 'ufpr.br', '11.°', '14', 'luciliadiniz.com', '11:56', '348', '428', 'ea', '15', 'médicosrevistacrescer.globo.com', 'pel…', 'saude.estadao.com.br', 'qq', 'di…ver', 'di…ver', 'vi…ver', '67', 'infart…ver', 'acredita…ver	', 'q…ver', 'a…ver', 'chat.whatsapp.com', '500mg', '450', '90', '200mg', 'e…ver', '30', 'n9', 'ñ', 'c', 'tb', '30', 'i', '07/04', '24', 'and', 'so', '’', '‘', '500', 'at', 'id=100031212156711', 'story_fbid=241150380268699', '03', '13/03/2020', '2/2', '25876', '01441', '2000', '5.000', 'the', '23:11', 'www.google.com', '21:35', 'ii', 'mg/kg', 'qd', '’', 'so', 'c', 'est', '»', 'noticias.r7.com', 'he', '19', 'www1.folha.uol.com.br', '23:22', '24', 'bloomberg.com', 'co…', 'google.com', 'to', 'is', 'it', 'oh', '川', '5:27', 'neh', 'brasil.elpais.com	', 'afff', '3foutputtype=amp', '36', '90', '400', 'c', '🥱', 'tô', 'mi', 'rs', 'correiobraziliense.com.br', 'r', 'agr', 'ô', '819', 'pre', '19', 'uai', '14', 'so', 'twitch.tv', '13', '2003', 'afz', 'hein', '35', 'media1.tenor.co', 'á', 'giphy', 'g1.globo.com', 'b382022', '2,5', '18.000.00', 'epoca.globo.com', 'veja.abril.com.br', 'id=100002238746462', 'story_fbid=3034985226586072', 'ê', 'o', 'aff', '39', '16', 'brakkkkkkkkkkkk', 'k', 'afffff', '8', '5,3', '15', '7.599', '3.120', 'gb', '64', '11', '16,5', '400', 'n', '18', 'ueh', '900', 'amp=1', '2o', 'bvsms.saude.gov.br/bvs/sus/comissoes.php', 'bvsms.saude.gov.br', 'http', 'usg=aovvaw2rb7swa3zpjklxt9uikurm', 'ved=2ahukewjslo6_7nlqahxvqd8khyh1dz0qfjahegqibrac', 'url=https', 'url=https', 'rct=j', 'source=web', 'sa=t', 'g', '25', 'नपूण‎', 'د', 'https://www.correiobraziliense.com.br/app/noticia/politica/2020/07/16/interna_politica,872688/amp.htm', 'muita', 'q', '2', '1', 'uol.com.br', 'om', 'apenas', 'antes', 'olha', 'assim', 'todo', 'twitch', 'pro', 'qualquer', 'gif', 'tenor', 'imagem', 'coisa', 'quanto', 'outros', 'algum', 'outra', 'ja', 'ainda', 'lá', 'vou', 'tão', 'falou', 'devem', 'podem', 'sinoussi', 'barré', 'françoise', 'tá', 'têm', 'pode', 'após', 'https', 'pois', 'uol', 'istoé', 'vai', 'toda', 'tudo', 'sim', 'bolsonarotemrazao', 'outro', 'onde', 'vez', 'pós', 'ter', 'vem', 'vão', 'google amp', 'né', 'tiraram', 'noticias', 'r7', 'eh', 'disse', 'algo', 'então', 'desse', 'dizer', 'quê', 'sendo', 'tbm', 'pra', 'aí', 'dessa', 'deve', 'sob', 'br', 'dar', 'dá', 'etc', 'ai', 'imagem pode', 'conter', 'cada', 'deu', 'vc', 'nao', 'aponta', 'pq', 'sobre', 'quer', 'ta', 'deixa', 'iwar0geexfnu6ezovclpbvw5x3z3yon5n1x6sido5p7ezuom_uwouu31rboay', 'fbclid=iwar2srohpl8geeqr8a9zyz17hpgmms4hh1q87ffficm_ek0v9srs5lgqsn68', '“', '”', 'p', '-', '…', '3', 'm', 'oglobo.globo.com', '10', '75', 'x', 'youtube.com', '20/03', '25/03', '26/03/2020', 's', '40', '60', '—', '460.361', '100', '100.000', 'istoe.com.br', '5', 'oq', '1.527.536', '122.025.818', '6.206.514', '1.152.283', '187.799.806', '627.047', '120.836.850', '831.381', '3.496.359', 'imperial.ac.uk', '1,6', '212.559.409', 'f', '529.779', '15.432', '72.398', '57.423', 'otempo.com.br', '206.087', '49.599.016', '4', '702.497', '250.182', '44.212', '11.457.197', '97.044', 'e/ou', 'noticias.uol.com.br', 'gizmodo.uol.com.br', '1.182.457', '0,2', '7', '니', 'usp=drivesdk', 'drive.google.com', '80', '20', 'clo2', '14x', '0:02', '0:00', 'ப', 'h', '4e', 'cmpid=copiaecola', '18:46', 'd', '27/03', '12h', 'av', 'ah', '²', '12', 'covidvisualizer.com', '17:30', '1,2kb/s', '19:34', 'è', '口', '444', 'u', '24/03/20', '08h38', '520', '09:50']

# %%
# nuvem de palavras dos usuários contra o uso da cloroquina no tratamento da Covid-19
wordcloudNeg = WordCloud(
    stopwords = list(STOPWORDS) + stopwords.words('portuguese') + stop,
    background_color = 'white',
    height = 1000,
    width = 2000,
    relative_scaling = 0.7,
    max_words = 100,
    collocations = False, # isso separa n-gramas
    random_state = 1
    ).generate(cloudNeg)

plt.figure(figsize=(15,10))
plt.imshow(wordcloudNeg)
plt.axis("off")
plt.show()

# %%
# nuvem de palavras dos usuários a favor do uso da cloroquina no tratamento da Covid-19
wordcloudPos = WordCloud(
    stopwords = list(STOPWORDS) + stopwords.words('portuguese') + stop,
    background_color = 'white',
    height = 1000,
    width = 2000,
    relative_scaling = 0.7,
    max_words = 100,
    collocations = False, # isso separa n-gramas
    random_state = 1
    ).generate(cloudPos)

plt.figure(figsize=(15,10))
plt.imshow(wordcloudPos)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Referência bibliográfica
# MOHAMMAD, Saif M.; SOBHANI, Parinaz; KIRITCHENKO, Svetlana. "Stance and Sentiment in Tweets". In: **ACM Transactions on Embedded Computing Systems**. V. 0. N. 0. 2016. Disponível em: <https://arxiv.org/pdf/1605.01655.pdf>. Acesso em 18 de setembro de 2020.
